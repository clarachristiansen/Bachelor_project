# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pmdarima as pm
import catboost as cb

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from pmdarima.metrics import smape
from sklearn.ensemble import RandomForestRegressor

# %%
# Load data
data = pd.read_parquet("Data/DSB_BDK_trainingset.parquet")

# %%
combinations = data[['visualiseringskode', 'station']].drop_duplicates().values
for strækning, station in combinations:
    print(data[(data['visualiseringskode'] == strækning) & (data['station'] == station)].shape)
# Out:
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)
# (2557, 209)

# %%
import ast
best_model_parameters = {}
model_params_sarima = pd.read_csv('Data/Best_model_parameters_SARIMA_strækning_station.csv')
list(model_params_sarima.items())
for i in range(model_params_sarima.shape[0]):
    tuple_result = ast.literal_eval(model_params_sarima['Key'][i])
    list_result = ast.literal_eval(model_params_sarima['Values'][i])
    best_model_parameters[tuple_result] = list_result

# %%
best_model_parameters
# Out:
# {(1, 0): [(1, 1, 1), (0, 0, 0, 0)],
#  (2, 0): [(3, 1, 5), (0, 0, 0, 0)],
#  (1, 1): [(0, 1, 2), (0, 0, 0, 0)],
#  (2, 2): [(1, 1, 1), (0, 0, 0, 0)],
#  (9, 2): [(1, 1, 3), (0, 0, 0, 0)],
#  (10, 3): [(1, 1, 3), (0, 0, 0, 0)],
#  (24, 3): [(2, 1, 1), (0, 0, 0, 0)],
#  (21, 4): [(1, 1, 1), (0, 0, 0, 0)],
#  (10, 5): [(5, 1, 2), (0, 0, 0, 0)],
#  (8, 5): [(0, 1, 2), (0, 0, 0, 0)],
#  (11, 6): [(1, 1, 3), (0, 0, 0, 0)],
#  (13, 6): [(1, 1, 3), (0, 0, 0, 0)],
#  (9, 6): [(1, 1, 1), (0, 0, 0, 0)],
#  (1, 7): [(1, 1, 1), (0, 0, 0, 0)],
#  (2, 8): [(1, 1, 1), (0, 0, 0, 0)],
#  (20, 9): [(0, 1, 2), (0, 0, 0, 0)],
#  (1, 10): [(1, 1, 1), (0, 0, 0, 0)],
#  (17, 11): [(2, 1, 3), (0, 0, 0, 0)],
#  (28, 12): [(1, 1, 3), (0, 0, 0, 0)],
#  (5, 12): [(0, 1, 2), (0, 0, 0, 0)],
#  (5, 13): [(1, 1, 1), (0, 0, 0, 0)],
#  (6, 13): [(1, 1, 1), (0, 0, 0, 0)],
#  (7, 13): [(0, 1, 2), (0, 0, 0, 0)],
#  (19, 14): [(1, 1, 1), (0, 0, 0, 0)],
#  (17, 15): [(0, 1, 2), (0, 0, 0, 0)],
#  (11, 16): [(1, 1, 3), (0, 0, 0, 0)],
#  (19, 17): [(0, 1, 2), (0, 0, 0, 0)],
#  (20, 17): [(0, 1, 2), (0, 0, 0, 0)],
#  (21, 17): [(1, 1, 1), (0, 0, 0, 0)],
#  (27, 17): [(2, 1, 1), (0, 0, 0, 0)],
#  (23, 18): [(1, 1, 3), (0, 0, 0, 0)],
#  (20, 19): [(0, 1, 2), (0, 0, 0, 0)],
#  (15, 20): [(2, 1, 2), (0, 0, 0, 0)],
#  (16, 20): [(1, 1, 3), (0, 0, 0, 0)],
#  (2, 21): [(1, 1, 1), (0, 0, 0, 0)],
#  (3, 21): [(1, 1, 1), (0, 0, 0, 0)],
#  (18, 22): [(1, 1, 1), (0, 0, 0, 0)],
#  (23, 22): [(5, 1, 5), (0, 0, 0, 0)],
#  (25, 22): [(1, 1, 3), (0, 0, 0, 0)],
#  (25, 23): [(1, 1, 1), (0, 0, 0, 0)],
#  (26, 23): [(0, 1, 2), (0, 0, 0, 0)],
#  (13, 24): [(1, 1, 3), (0, 0, 0, 0)],
#  (15, 24): [(3, 1, 3), (0, 0, 0, 0)],
#  (13, 25): [(1, 1, 1), (0, 0, 0, 0)],
#  (14, 25): [(1, 1, 2), (0, 0, 0, 0)],
#  (20, 26): [(0, 1, 2), (0, 0, 0, 0)],
#  (11, 27): [(1, 1, 3), (0, 0, 0, 0)],
#  (24, 28): [(3, 1, 1), (0, 0, 0, 0)],
#  (14, 29): [(3, 1, 1), (0, 0, 0, 0)],
#  (26, 30): [(1, 1, 3), (0, 0, 0, 0)],
#  (16, 31): [(1, 1, 1), (0, 0, 0, 0)],
#  (18, 31): [(1, 1, 1), (0, 0, 0, 0)],
#  (27, 31): [(2, 1, 2), (0, 0, 0, 0)],
#  (28, 32): [(0, 1, 2), (0, 0, 0, 0)],
#  (16, 33): [(1, 1, 3), (0, 0, 0, 0)],
#  (17, 33): [(3, 1, 4), (0, 0, 0, 0)],
#  (19, 33): [(1, 1, 3), (0, 0, 0, 0)],
#  (6, 34): [(1, 1, 1), (0, 0, 0, 0)],
#  (9, 34): [(1, 1, 1), (0, 0, 0, 0)],
#  (12, 35): [(1, 1, 1), (0, 0, 0, 0)],
#  (16, 36): [(1, 1, 3), (0, 0, 0, 0)],
#  (28, 37): [(1, 1, 1), (0, 0, 0, 0)],
#  (7, 37): [(0, 1, 1), (0, 0, 0, 0)],
#  (8, 37): [(1, 1, 1), (0, 0, 0, 0)],
#  (6, 38): [(1, 1, 1), (0, 0, 0, 0)],
#  (3, 39): [(1, 1, 2), (0, 0, 0, 0)],
#  (4, 39): [(3, 1, 1), (0, 0, 0, 0)],
#  (5, 39): [(1, 1, 2), (0, 0, 0, 0)],
#  (14, 40): [(2, 1, 2), (0, 0, 0, 0)],
#  (24, 41): [(3, 1, 2), (0, 0, 0, 0)],
#  (11, 42): [(2, 1, 3), (0, 0, 0, 0)],
#  (12, 42): [(1, 1, 2), (0, 0, 0, 0)],
#  (4, 43): [(1, 1, 4), (0, 0, 0, 0)],
#  (8, 44): [(0, 1, 2), (0, 0, 0, 0)],
#  (3, 45): [(1, 1, 3), (0, 0, 0, 0)],
#  (5, 46): [(1, 1, 1), (0, 0, 0, 0)],
#  (9, 46): [(0, 1, 3), (0, 0, 0, 0)],
#  (25, 47): [(1, 1, 3), (0, 0, 0, 0)]}

# %%
def custom_cross_val_predict(estimator, y, X=None, cv=None, verbose=0, averaging="mean", return_raw_predictions=False, initial=2555):
    """Generate cross-validated estimates for each input data point
    
    Parameters
    ----------
    estimator : tuple
        A tuple containing two estimators. The first estimator should be the ARIMA model
        and the second one should be the Random Forest model.

    y : array-like or iterable, shape=(n_samples,)
        The time-series array.

    X : array-like, shape=[n_obs, n_vars], optional (default=None)
        An optional 2-d array of exogenous variables.

    cv : BaseTSCrossValidator or None, optional (default=None)
        An instance of cross-validation. If None, will use a RollingForecastCV.
        Note that for cross-validation predictions, the CV step cannot exceed
        the CV horizon, or there will be a gap between fold predictions.

    verbose : integer, optional
        The verbosity level.

    averaging : str or callable, one of ["median", "mean"] (default="mean")
        Unlike normal CV, time series CV might have different folds (windows)
        forecasting the same time step. After all forecast windows are made,
        we build a matrix of y x n_folds, populating each fold's forecasts like
        so::

            nan nan nan  # training samples
            nan nan nan
            nan nan nan
            nan nan nan
              1 nan nan  # test samples
              4   3 nan
              3 2.5 3.5
            nan   6   5
            nan nan   4

        We then average each time step's forecasts to end up with our final
        prediction results.

    return_raw_predictions : bool (default=False)
        If True, raw predictions are returned instead of averaged ones.
        This results in a y x h matrix. For example, if h=3, and step=1 then:

            nan nan nan # training samples
            nan nan nan
            nan nan nan
            nan nan nan
            1   4   2   # test samples
            2   5   7
            8   9   1
            nan nan nan
            nan nan nan

        First column contains all one-step-ahead-predictions, second column all
        two-step-ahead-predictions etc. Further metrics can then be calculated
        as desired.

    Returns
    -------
    predictions : array-like, shape=(n_samples,)
        The predicted values.

    """

    def indexable(*iterables):
        """Internal utility to handle input types"""
        results = []
        for iterable in iterables:
            if not hasattr(iterable, "__iter__"):
                raise ValueError("Input {!r} is not indexable".format(iterable))
            results.append(iterable)
        return results

    def check_cv(cv, initial = 2555):
        """Internal utility to check cv"""
        if cv is None:
            from pmdarima.model_selection import RollingForecastCV
            cv = RollingForecastCV(initial=initial, step=1, h=1)
        return cv

    def check_endog(y, copy=True, preserve_series=False):
        """Internal utility to check endogenous variable"""
        from pmdarima.utils import check_endog
        return check_endog(y, copy=copy, preserve_series=preserve_series)

    def _check_averaging(averaging):
        """Internal utility to check averaging"""
        if averaging == "mean":
            return np.nanmean
        elif averaging == "median":
            return np.nanmedian
        elif callable(averaging):
            return averaging
        else:
            raise ValueError("Unknown averaging method: {}".format(averaging))

    def _fit_and_predict(fold, estimator_tuple, y, X, train, test, verbose=0):
        """Internal utility to fit and predict"""
        arima_model = estimator_tuple
        # Fit ARIMA model
        arima_model.fit(y[train]) # X=X.iloc[train, :]
        # Predict with ARIMA model
        train_predictions = arima_model.predict_in_sample()
        arima_pred = arima_model.predict(n_periods=len(test))

        # Calculate residuals for RF input
        arima_residuals_train = train_predictions - y[train]
        
        # Model
        model = cb.CatBoostRegressor(objective = 'RMSE', iterations=20, learning_rate=0.1, max_depth=5) 
        # Define the parameters for the CatBoost classifier
        #param = {'objective':'reg:squarederror', 'booster':'gbtree', 'max_depth': 5}
 

        #steps = 20  # The number of training iterations

        # Train the model
        model.fit(X.iloc[train, :], arima_residuals_train)

        # Predict the labels of the test set
        preds = model.predict(X.iloc[test, :])
        # Overall prediction residuals = pred - true <=> true = pred - residuals
        overall_pred = np.array(max(min(1, arima_pred[0] - preds), 0)) # make sure it is in [0;1]

        return overall_pred, test, np.array(arima_pred) #arima_residuals_test

    y, X = indexable(y, X)
    y = check_endog(y, copy=False, preserve_series=True)
    cv = check_cv(cv, initial)
    avgfunc = _check_averaging(averaging)

    if cv.step > cv.horizon:
        raise ValueError("CV step cannot be > CV horizon, or there will be a gap in predictions between folds")

    prediction_blocks = [
        _fit_and_predict(fold,
                         estimator,
                         y,
                         X,
                         train=train,
                         test=test,
                         verbose=verbose,)  # TODO: fit params?
        for fold, (train, test) in enumerate(cv.split(y, X))]

    pred_matrix = np.ones((y.shape[0], len(prediction_blocks))) * np.nan
    arima_pred = []
    for i, (pred_block, test_indices, arima_block) in enumerate(prediction_blocks):
        pred_matrix[test_indices, i] = pred_block
        arima_pred.append(arima_block)

    if return_raw_predictions:
        predictions = np.ones((y.shape[0], cv.horizon)) * np.nan
        for pred_block, test_indices in prediction_blocks:
            predictions[test_indices[0]] = pred_block
        return predictions

    test_mask = ~(np.isnan(pred_matrix).all(axis=1))
    predictions = pred_matrix[test_mask]



    # Calculate CV score
    cv_scores = []
    cv_scores_arima = []
    for fold, (train, test) in enumerate(cv.split(y, X)):
        fold_predictions = pred_matrix[test, fold]
        fold_score = mean_squared_error(y[test], fold_predictions)
        fold_arima_score = mean_squared_error(y[test], arima_pred[fold])
        cv_scores.append(fold_score)
        cv_scores_arima.append(fold_arima_score)

    # Compute overall CV score
    score = np.mean(cv_scores)
    arima_score = np.mean(cv_scores_arima)

    return avgfunc(predictions, axis=1), score,  arima_score

# %%
import warnings
warnings.filterwarnings('ignore')

results_strækning_station = {}
combinations = data[['visualiseringskode', 'station']].drop_duplicates().values
MSEs = []
MSEs_arima = []
random_state = 42
initial_start = 2500
preds = {}

for strækning, station in combinations[:10]:
    y = data[(data['visualiseringskode'] == strækning) & (data['station'] == station)]['togpunktlighed']
    X = data[(data['visualiseringskode'] == strækning) & (data['station'] == station)].iloc[:,1:]
    arima_model = pm.arima.ARIMA(order = best_model_parameters[strækning, station][0], seasonal_order=best_model_parameters[strækning, station][1])

    pred, mse, mse_arima = custom_cross_val_predict((arima_model), y, X, cv=None, verbose=1, averaging="mean", return_raw_predictions=False, initial=initial_start)
    # output = prediction per fold. 
    MSEs.append(mse)
    MSEs_arima.append(mse_arima)
    preds[(strækning, station)] = pred
    # initial = 2457 - 100 fold, 10 combinations, n_estimators=100 -> 61 min
# Out:
# 0:	learn: 0.1268810	total: 2.9ms	remaining: 55.1ms
# 1:	learn: 0.1250968	total: 4.54ms	remaining: 40.9ms
# 2:	learn: 0.1236557	total: 6.56ms	remaining: 37.2ms
# 3:	learn: 0.1214342	total: 8.09ms	remaining: 32.4ms
# 4:	learn: 0.1195992	total: 10.3ms	remaining: 30.8ms
# 5:	learn: 0.1185350	total: 11.9ms	remaining: 27.7ms
# 6:	learn: 0.1173902	total: 13.4ms	remaining: 24.9ms
# 7:	learn: 0.1165730	total: 15.1ms	remaining: 22.6ms
# 8:	learn: 0.1155555	total: 16.7ms	remaining: 20.5ms
# 9:	learn: 0.1144190	total: 18.4ms	remaining: 18.4ms
# 10:	learn: 0.1137798	total: 20.1ms	remaining: 16.5ms
# 11:	learn: 0.1127607	total: 21.6ms	remaining: 14.4ms
# 12:	learn: 0.1120048	total: 23.2ms	remaining: 12.5ms
# 13:	learn: 0.1112818	total: 24.7ms	remaining: 10.6ms
# 14:	learn: 0.1106655	total: 26.4ms	remaining: 8.79ms
# 15:	learn: 0.1102130	total: 28.1ms	remaining: 7.02ms
# 16:	learn: 0.1099868	total: 29.7ms	remaining: 5.24ms
# 17:	learn: 0.1097802	total: 31.3ms	remaining: 3.48ms
# 18:	learn: 0.1096947	total: 32.8ms	remaining: 1.73ms
# 19:	learn: 0.1093447	total: 34.4ms	remaining: 0us
# 0:	learn: 0.1271281	total: 2.04ms	remaining: 38.9ms
# 1:	learn: 0.1249451	total: 3.66ms	remaining: 32.9ms
# 2:	learn: 0.1230621	total: 5.51ms	remaining: 31.2ms
# 3:	learn: 0.1210659	total: 7.19ms	remaining: 28.8ms
# 4:	learn: 0.1193175	total: 8.89ms	remaining: 26.7ms
# 5:	learn: 0.1182264	total: 10.6ms	remaining: 24.6ms
# 6:	learn: 0.1171072	total: 12.7ms	remaining: 23.6ms
# 7:	learn: 0.1165716	total: 14.3ms	remaining: 21.4ms
# 8:	learn: 0.1154086	total: 15.8ms	remaining: 19.3ms
# 9:	learn: 0.1142736	total: 17.4ms	remaining: 17.4ms
# 10:	learn: 0.1132974	total: 19.3ms	remaining: 15.8ms
# 11:	learn: 0.1124495	total: 21ms	remaining: 14ms
# 12:	learn: 0.1117831	total: 22.8ms	remaining: 12.3ms
# 13:	learn: 0.1110407	total: 24.5ms	remaining: 10.5ms
# 14:	learn: 0.1105344	total: 26ms	remaining: 8.67ms
# 15:	learn: 0.1100981	total: 27.5ms	remaining: 6.88ms
# 16:	learn: 0.1098700	total: 29.1ms	remaining: 5.13ms
# 17:	learn: 0.1096250	total: 30.6ms	remaining: 3.4ms
# 18:	learn: 0.1094330	total: 32.3ms	remaining: 1.7ms
# 19:	learn: 0.1087518	total: 33.9ms	remaining: 0us
# 0:	learn: 0.1268423	total: 1.64ms	remaining: 31.2ms
# 1:	learn: 0.1249188	total: 3.65ms	remaining: 32.8ms
# 2:	learn: 0.1234766	total: 5.58ms	remaining: 31.7ms
# 3:	learn: 0.1216606	total: 7.1ms	remaining: 28.4ms
# 4:	learn: 0.1200613	total: 8.68ms	remaining: 26ms
# 5:	learn: 0.1190552	total: 10.3ms	remaining: 24.1ms
# 6:	learn: 0.1177843	total: 11.8ms	remaining: 22ms
# 7:	learn: 0.1166185	total: 13.5ms	remaining: 20.2ms
# 8:	learn: 0.1153342	total: 15ms	remaining: 18.4ms
# 9:	learn: 0.1144087	total: 16.7ms	remaining: 16.7ms
# 10:	learn: 0.1134731	total: 18.5ms	remaining: 15.2ms
# 11:	learn: 0.1129881	total: 20ms	remaining: 13.3ms
# 12:	learn: 0.1123368	total: 21.7ms	remaining: 11.7ms
# 13:	learn: 0.1115556	total: 23.2ms	remaining: 9.95ms
# 14:	learn: 0.1109999	total: 24.7ms	remaining: 8.23ms
# 15:	learn: 0.1105451	total: 26.3ms	remaining: 6.57ms
# 16:	learn: 0.1103168	total: 28ms	remaining: 4.95ms
# 17:	learn: 0.1100651	total: 29.7ms	remaining: 3.3ms
# 18:	learn: 0.1099829	total: 31.6ms	remaining: 1.66ms
# 19:	learn: 0.1096071	total: 34ms	remaining: 0us
# 0:	learn: 0.1268057	total: 1.76ms	remaining: 33.5ms
# 1:	learn: 0.1248817	total: 3.42ms	remaining: 30.7ms
# 2:	learn: 0.1234379	total: 5.77ms	remaining: 32.7ms
# 3:	learn: 0.1216268	total: 7.34ms	remaining: 29.4ms
# 4:	learn: 0.1200816	total: 8.98ms	remaining: 26.9ms
# 5:	learn: 0.1190741	total: 10.7ms	remaining: 25ms
# 6:	learn: 0.1177981	total: 12.4ms	remaining: 23ms
# 7:	learn: 0.1165428	total: 14.1ms	remaining: 21.2ms
# 8:	learn: 0.1153426	total: 16ms	remaining: 19.5ms
# 9:	learn: 0.1144531	total: 17.7ms	remaining: 17.7ms
# 10:	learn: 0.1135356	total: 19.3ms	remaining: 15.8ms
# 11:	learn: 0.1126517	total: 21.6ms	remaining: 14.4ms
# 12:	learn: 0.1117003	total: 23.4ms	remaining: 12.6ms
# 13:	learn: 0.1109924	total: 25.2ms	remaining: 10.8ms
# 14:	learn: 0.1103965	total: 26.9ms	remaining: 8.96ms
# 15:	learn: 0.1100194	total: 28.4ms	remaining: 7.1ms
# 16:	learn: 0.1097831	total: 30ms	remaining: 5.3ms
# 17:	learn: 0.1095354	total: 31.5ms	remaining: 3.5ms
# 18:	learn: 0.1093785	total: 33.3ms	remaining: 1.75ms
# 19:	learn: 0.1090101	total: 35.6ms	remaining: 0us
# 0:	learn: 0.1270556	total: 1.74ms	remaining: 33ms
# 1:	learn: 0.1248753	total: 3.91ms	remaining: 35.2ms
# 2:	learn: 0.1229938	total: 5.98ms	remaining: 33.9ms
# 3:	learn: 0.1209991	total: 7.76ms	remaining: 31ms
# 4:	learn: 0.1191672	total: 9.85ms	remaining: 29.5ms
# 5:	learn: 0.1180915	total: 12.1ms	remaining: 28.3ms
# 6:	learn: 0.1170227	total: 14.2ms	remaining: 26.4ms
# 7:	learn: 0.1162200	total: 16.3ms	remaining: 24.5ms
# 8:	learn: 0.1151367	total: 18.3ms	remaining: 22.4ms
# 9:	learn: 0.1141756	total: 20.4ms	remaining: 20.4ms
# 10:	learn: 0.1134032	total: 22.8ms	remaining: 18.7ms
# 11:	learn: 0.1125817	total: 25ms	remaining: 16.7ms
# 12:	learn: 0.1119048	total: 26.8ms	remaining: 14.4ms
# 13:	learn: 0.1111935	total: 29.3ms	remaining: 12.6ms
# 14:	learn: 0.1104566	total: 31.9ms	remaining: 10.6ms
# 15:	learn: 0.1101107	total: 33.8ms	remaining: 8.44ms
# 16:	learn: 0.1100025	total: 37.1ms	remaining: 6.54ms
# 17:	learn: 0.1097651	total: 40.4ms	remaining: 4.49ms
# 18:	learn: 0.1095733	total: 42.8ms	remaining: 2.25ms
# 19:	learn: 0.1091926	total: 44.8ms	remaining: 0us
# 0:	learn: 0.1270306	total: 1.64ms	remaining: 31.1ms
# 1:	learn: 0.1248506	total: 3.25ms	remaining: 29.3ms
# 2:	learn: 0.1229696	total: 4.91ms	remaining: 27.8ms
# 3:	learn: 0.1209751	total: 6.37ms	remaining: 25.5ms
# 4:	learn: 0.1191438	total: 7.9ms	remaining: 23.7ms
# 5:	learn: 0.1180684	total: 9.56ms	remaining: 22.3ms
# 6:	learn: 0.1169996	total: 11.2ms	remaining: 20.8ms
# 7:	learn: 0.1161971	total: 13.4ms	remaining: 20.1ms
# 8:	learn: 0.1151140	total: 15ms	remaining: 18.3ms
# 9:	learn: 0.1141532	total: 16.6ms	remaining: 16.6ms
# 10:	learn: 0.1133809	total: 18.1ms	remaining: 14.8ms
# 11:	learn: 0.1125596	total: 19.7ms	remaining: 13.1ms
# 12:	learn: 0.1118828	total: 21.2ms	remaining: 11.4ms
# 13:	learn: 0.1111718	total: 22.8ms	remaining: 9.79ms
# 14:	learn: 0.1104351	total: 25.1ms	remaining: 8.37ms
# 15:	learn: 0.1100892	total: 26.7ms	remaining: 6.67ms
# 16:	learn: 0.1099811	total: 28.4ms	remaining: 5.01ms
# 17:	learn: 0.1097439	total: 29.8ms	remaining: 3.32ms
# 18:	learn: 0.1095520	total: 31.2ms	remaining: 1.64ms
# 19:	learn: 0.1091714	total: 32.8ms	remaining: 0us
# 0:	learn: 0.1270141	total: 1.63ms	remaining: 31ms
# 1:	learn: 0.1248343	total: 3.32ms	remaining: 29.9ms
# 2:	learn: 0.1229531	total: 5.01ms	remaining: 28.4ms
# 3:	learn: 0.1209585	total: 6.57ms	remaining: 26.3ms
# 4:	learn: 0.1191533	total: 8.04ms	remaining: 24.1ms
# 5:	learn: 0.1180781	total: 9.67ms	remaining: 22.6ms
# 6:	learn: 0.1170080	total: 11.4ms	remaining: 21.2ms
# 7:	learn: 0.1162041	total: 13.3ms	remaining: 20ms
# 8:	learn: 0.1151175	total: 15ms	remaining: 18.3ms
# 9:	learn: 0.1141548	total: 16.4ms	remaining: 16.4ms
# 10:	learn: 0.1133807	total: 18ms	remaining: 14.8ms
# 11:	learn: 0.1125583	total: 19.7ms	remaining: 13.1ms
# 12:	learn: 0.1118808	total: 21.2ms	remaining: 11.4ms
# 13:	learn: 0.1111683	total: 22.8ms	remaining: 9.77ms
# 14:	learn: 0.1106388	total: 24.5ms	remaining: 8.16ms
# 15:	learn: 0.1102024	total: 26.2ms	remaining: 6.54ms
# 16:	learn: 0.1099962	total: 27.7ms	remaining: 4.9ms
# 17:	learn: 0.1098801	total: 29.5ms	remaining: 3.28ms
# 18:	learn: 0.1097965	total: 31.1ms	remaining: 1.63ms
# 19:	learn: 0.1094504	total: 32.6ms	remaining: 0us
# 0:	learn: 0.1269913	total: 1.61ms	remaining: 30.6ms
# 1:	learn: 0.1248117	total: 3.24ms	remaining: 29.2ms
# 2:	learn: 0.1229305	total: 4.9ms	remaining: 27.8ms
# 3:	learn: 0.1209362	total: 6.44ms	remaining: 25.8ms
# 4:	learn: 0.1191309	total: 8.05ms	remaining: 24.2ms
# 5:	learn: 0.1177093	total: 9.79ms	remaining: 22.8ms
# 6:	learn: 0.1166483	total: 11.7ms	remaining: 21.8ms
# 7:	learn: 0.1158547	total: 13.3ms	remaining: 20ms
# 8:	learn: 0.1147996	total: 15ms	remaining: 18.4ms
# 9:	learn: 0.1139174	total: 16.8ms	remaining: 16.8ms
# 10:	learn: 0.1131502	total: 18.4ms	remaining: 15.1ms
# 11:	learn: 0.1124685	total: 20.2ms	remaining: 13.4ms
# 12:	learn: 0.1117934	total: 21.8ms	remaining: 11.7ms
# 13:	learn: 0.1110553	total: 23.7ms	remaining: 10.2ms
# 14:	learn: 0.1105076	total: 25.3ms	remaining: 8.45ms
# 15:	learn: 0.1100464	total: 26.8ms	remaining: 6.7ms
# 16:	learn: 0.1099185	total: 28.3ms	remaining: 5ms
# 17:	learn: 0.1097691	total: 29.8ms	remaining: 3.32ms
# 18:	learn: 0.1096854	total: 31.3ms	remaining: 1.65ms
# 19:	learn: 0.1093263	total: 33ms	remaining: 0us
# 0:	learn: 0.1266944	total: 1.71ms	remaining: 32.5ms
# 1:	learn: 0.1247761	total: 3.54ms	remaining: 31.8ms
# 2:	learn: 0.1233309	total: 5.25ms	remaining: 29.8ms
# 3:	learn: 0.1215236	total: 6.76ms	remaining: 27ms
# 4:	learn: 0.1197930	total: 8.31ms	remaining: 24.9ms
# 5:	learn: 0.1183478	total: 10.3ms	remaining: 24.1ms
# 6:	learn: 0.1172494	total: 11.9ms	remaining: 22.1ms
# 7:	learn: 0.1164322	total: 13.4ms	remaining: 20.1ms
# 8:	learn: 0.1151317	total: 15ms	remaining: 18.3ms
# 9:	learn: 0.1140465	total: 16.6ms	remaining: 16.6ms
# 10:	learn: 0.1131619	total: 18ms	remaining: 14.8ms
# 11:	learn: 0.1127193	total: 19.5ms	remaining: 13ms
# 12:	learn: 0.1117095	total: 21.1ms	remaining: 11.4ms
# 13:	learn: 0.1109776	total: 22.8ms	remaining: 9.78ms
# 14:	learn: 0.1103221	total: 24.4ms	remaining: 8.14ms
# 15:	learn: 0.1101579	total: 26ms	remaining: 6.49ms
# 16:	learn: 0.1099325	total: 27.5ms	remaining: 4.85ms
# 17:	learn: 0.1097025	total: 29ms	remaining: 3.22ms
# 18:	learn: 0.1096219	total: 30.6ms	remaining: 1.61ms
# 19:	learn: 0.1092343	total: 32.2ms	remaining: 0us
# 0:	learn: 0.1269505	total: 1.64ms	remaining: 31.1ms
# 1:	learn: 0.1247728	total: 3.29ms	remaining: 29.6ms
# 2:	learn: 0.1228928	total: 5.13ms	remaining: 29.1ms
# 3:	learn: 0.1209022	total: 6.75ms	remaining: 27ms
# 4:	learn: 0.1191245	total: 8.25ms	remaining: 24.7ms
# 5:	learn: 0.1176941	total: 9.85ms	remaining: 23ms
# 6:	learn: 0.1166327	total: 11.5ms	remaining: 21.4ms
# 7:	learn: 0.1158381	total: 13.1ms	remaining: 19.7ms
# 8:	learn: 0.1147650	total: 14.8ms	remaining: 18ms
# 9:	learn: 0.1138826	total: 16.4ms	remaining: 16.4ms
# 10:	learn: 0.1131215	total: 18ms	remaining: 14.8ms
# 11:	learn: 0.1124412	total: 19.8ms	remaining: 13.2ms
# 12:	learn: 0.1117688	total: 21.4ms	remaining: 11.5ms
# 13:	learn: 0.1110324	total: 23.1ms	remaining: 9.88ms
# 14:	learn: 0.1104923	total: 24.5ms	remaining: 8.18ms
# 15:	learn: 0.1100353	total: 26ms	remaining: 6.51ms
# 16:	learn: 0.1098147	total: 27.6ms	remaining: 4.86ms
# 17:	learn: 0.1096670	total: 29.1ms	remaining: 3.23ms
# 18:	learn: 0.1095793	total: 31ms	remaining: 1.63ms
# 19:	learn: 0.1092382	total: 32.6ms	remaining: 0us
# 0:	learn: 0.1266940	total: 2.12ms	remaining: 40.3ms
# 1:	learn: 0.1247686	total: 3.8ms	remaining: 34.2ms
# 2:	learn: 0.1233254	total: 5.38ms	remaining: 30.5ms
# 3:	learn: 0.1215105	total: 6.89ms	remaining: 27.6ms
# 4:	learn: 0.1199789	total: 8.59ms	remaining: 25.8ms
# 5:	learn: 0.1185687	total: 10.2ms	remaining: 23.8ms
# 6:	learn: 0.1174467	total: 11.8ms	remaining: 21.9ms
# 7:	learn: 0.1164011	total: 13.3ms	remaining: 20ms
# 8:	learn: 0.1151828	total: 15ms	remaining: 18.3ms
# 9:	learn: 0.1142569	total: 16.6ms	remaining: 16.6ms
# 10:	learn: 0.1132912	total: 18.2ms	remaining: 14.9ms
# 11:	learn: 0.1126256	total: 19.8ms	remaining: 13.2ms
# 12:	learn: 0.1119573	total: 21.4ms	remaining: 11.5ms
# 13:	learn: 0.1112472	total: 23ms	remaining: 9.87ms
# 14:	learn: 0.1107127	total: 24.6ms	remaining: 8.19ms
# 15:	learn: 0.1102769	total: 26.1ms	remaining: 6.53ms
# 16:	learn: 0.1100446	total: 27.7ms	remaining: 4.9ms
# 17:	learn: 0.1097949	total: 29.7ms	remaining: 3.3ms
# 18:	learn: 0.1097092	total: 32ms	remaining: 1.68ms
# 19:	learn: 0.1092606	total: 33.8ms	remaining: 0us
# 0:	learn: 0.1274319	total: 1.53ms	remaining: 29.2ms
# 1:	learn: 0.1252263	total: 3.19ms	remaining: 28.7ms
# 2:	learn: 0.1237663	total: 5.54ms	remaining: 31.4ms
# 3:	learn: 0.1219598	total: 7.01ms	remaining: 28ms
# 4:	learn: 0.1203278	total: 8.6ms	remaining: 25.8ms
# 5:	learn: 0.1191948	total: 10.1ms	remaining: 23.6ms
# 6:	learn: 0.1180305	total: 11.6ms	remaining: 21.6ms
# 7:	learn: 0.1168505	total: 13.3ms	remaining: 19.9ms
# 8:	learn: 0.1158158	total: 14.9ms	remaining: 18.3ms
# 9:	learn: 0.1149275	total: 16.5ms	remaining: 16.5ms
# 10:	learn: 0.1139280	total: 18.1ms	remaining: 14.8ms
# 11:	learn: 0.1130245	total: 19.8ms	remaining: 13.2ms
# 12:	learn: 0.1123565	total: 21.4ms	remaining: 11.5ms
# 13:	learn: 0.1116153	total: 23.2ms	remaining: 9.93ms
# 14:	learn: 0.1110801	total: 24.7ms	remaining: 8.25ms
# 15:	learn: 0.1106179	total: 26.3ms	remaining: 6.57ms
# 16:	learn: 0.1103832	total: 27.8ms	remaining: 4.91ms
# 17:	learn: 0.1101352	total: 29.4ms	remaining: 3.27ms
# 18:	learn: 0.1100476	total: 30.9ms	remaining: 1.63ms
# 19:	learn: 0.1096992	total: 32.6ms	remaining: 0us
# 0:	learn: 0.1266572	total: 1.72ms	remaining: 32.6ms
# 1:	learn: 0.1247310	total: 3.87ms	remaining: 34.8ms
# 2:	learn: 0.1232892	total: 5.56ms	remaining: 31.5ms
# 3:	learn: 0.1214730	total: 7.05ms	remaining: 28.2ms
# 4:	learn: 0.1198983	total: 8.59ms	remaining: 25.8ms
# 5:	learn: 0.1188950	total: 10.2ms	remaining: 23.8ms
# 6:	learn: 0.1176259	total: 12.3ms	remaining: 22.9ms
# 7:	learn: 0.1163761	total: 14.1ms	remaining: 21.1ms
# 8:	learn: 0.1153716	total: 15.7ms	remaining: 19.2ms
# 9:	learn: 0.1143791	total: 18.3ms	remaining: 18.3ms
# 10:	learn: 0.1134350	total: 19.9ms	remaining: 16.2ms
# 11:	learn: 0.1124561	total: 21.4ms	remaining: 14.3ms
# 12:	learn: 0.1114506	total: 22.9ms	remaining: 12.4ms
# 13:	learn: 0.1107393	total: 24.6ms	remaining: 10.6ms
# 14:	learn: 0.1101043	total: 26.1ms	remaining: 8.7ms
# 15:	learn: 0.1096768	total: 27.7ms	remaining: 6.93ms
# 16:	learn: 0.1094497	total: 29.2ms	remaining: 5.16ms
# 17:	learn: 0.1092111	total: 31.1ms	remaining: 3.46ms
# 18:	learn: 0.1090449	total: 32.8ms	remaining: 1.73ms
# 19:	learn: 0.1085993	total: 34.3ms	remaining: 0us
# 0:	learn: 0.1266323	total: 1.73ms	remaining: 32.9ms
# 1:	learn: 0.1247055	total: 3.48ms	remaining: 31.3ms
# 2:	learn: 0.1232641	total: 5.15ms	remaining: 29.2ms
# 3:	learn: 0.1214483	total: 7.39ms	remaining: 29.6ms
# 4:	learn: 0.1199053	total: 9.16ms	remaining: 27.5ms
# 5:	learn: 0.1188994	total: 11.6ms	remaining: 27ms
# 6:	learn: 0.1176261	total: 13.4ms	remaining: 24.8ms
# 7:	learn: 0.1163679	total: 14.9ms	remaining: 22.4ms
# 8:	learn: 0.1151583	total: 16.5ms	remaining: 20.2ms
# 9:	learn: 0.1143354	total: 18.2ms	remaining: 18.2ms
# 10:	learn: 0.1133832	total: 20.4ms	remaining: 16.7ms
# 11:	learn: 0.1127838	total: 22ms	remaining: 14.7ms
# 12:	learn: 0.1119965	total: 23.5ms	remaining: 12.7ms
# 13:	learn: 0.1112498	total: 25.2ms	remaining: 10.8ms
# 14:	learn: 0.1106124	total: 26.8ms	remaining: 8.93ms
# 15:	learn: 0.1101685	total: 28.4ms	remaining: 7.11ms
# 16:	learn: 0.1099363	total: 30ms	remaining: 5.29ms
# 17:	learn: 0.1096938	total: 31.6ms	remaining: 3.51ms
# 18:	learn: 0.1095215	total: 33.5ms	remaining: 1.76ms
# 19:	learn: 0.1090708	total: 35.1ms	remaining: 0us
# 0:	learn: 0.1266214	total: 1.68ms	remaining: 31.9ms
# 1:	learn: 0.1246941	total: 3.52ms	remaining: 31.6ms
# 2:	learn: 0.1232541	total: 5.45ms	remaining: 30.9ms
# 3:	learn: 0.1214382	total: 7.29ms	remaining: 29.2ms
# 4:	learn: 0.1198547	total: 9ms	remaining: 27ms
# 5:	learn: 0.1188511	total: 10.6ms	remaining: 24.7ms
# 6:	learn: 0.1175834	total: 12.2ms	remaining: 22.7ms
# 7:	learn: 0.1163285	total: 14.1ms	remaining: 21.2ms
# 8:	learn: 0.1151182	total: 15.7ms	remaining: 19.1ms
# 9:	learn: 0.1142472	total: 17.1ms	remaining: 17.1ms
# 10:	learn: 0.1133424	total: 18.8ms	remaining: 15.3ms
# 11:	learn: 0.1128934	total: 20.4ms	remaining: 13.6ms
# 12:	learn: 0.1118511	total: 22.3ms	remaining: 12ms
# 13:	learn: 0.1111234	total: 24ms	remaining: 10.3ms
# 14:	learn: 0.1104183	total: 25.6ms	remaining: 8.53ms
# 15:	learn: 0.1100462	total: 27.1ms	remaining: 6.76ms
# 16:	learn: 0.1098133	total: 28.9ms	remaining: 5.1ms
# 17:	learn: 0.1095716	total: 30.4ms	remaining: 3.38ms
# 18:	learn: 0.1093999	total: 31.9ms	remaining: 1.68ms
# 19:	learn: 0.1090254	total: 33.7ms	remaining: 0us
# 0:	learn: 0.1266025	total: 2.49ms	remaining: 47.3ms
# 1:	learn: 0.1246751	total: 4.43ms	remaining: 39.9ms
# 2:	learn: 0.1232353	total: 6.01ms	remaining: 34.1ms
# 3:	learn: 0.1214199	total: 7.59ms	remaining: 30.4ms
# 4:	learn: 0.1198922	total: 9.19ms	remaining: 27.6ms
# 5:	learn: 0.1184404	total: 11.6ms	remaining: 27.1ms
# 6:	learn: 0.1172845	total: 13.2ms	remaining: 24.5ms
# 7:	learn: 0.1161443	total: 14.8ms	remaining: 22.2ms
# 8:	learn: 0.1151344	total: 16.4ms	remaining: 20.1ms
# 9:	learn: 0.1142708	total: 18.5ms	remaining: 18.5ms
# 10:	learn: 0.1136418	total: 20ms	remaining: 16.4ms
# 11:	learn: 0.1131970	total: 21.6ms	remaining: 14.4ms
# 12:	learn: 0.1125026	total: 23.3ms	remaining: 12.6ms
# 13:	learn: 0.1117155	total: 25.7ms	remaining: 11ms
# 14:	learn: 0.1110445	total: 27.7ms	remaining: 9.25ms
# 15:	learn: 0.1106194	total: 29.7ms	remaining: 7.42ms
# 16:	learn: 0.1103929	total: 31.3ms	remaining: 5.52ms
# 17:	learn: 0.1101451	total: 33.6ms	remaining: 3.73ms
# 18:	learn: 0.1099612	total: 35.3ms	remaining: 1.86ms
# 19:	learn: 0.1092284	total: 36.9ms	remaining: 0us
# 0:	learn: 0.1265949	total: 2.29ms	remaining: 43.5ms
# 1:	learn: 0.1246739	total: 4.61ms	remaining: 41.5ms
# 2:	learn: 0.1232294	total: 6.24ms	remaining: 35.4ms
# 3:	learn: 0.1214175	total: 7.7ms	remaining: 30.8ms
# 4:	learn: 0.1198422	total: 9.37ms	remaining: 28.1ms
# 5:	learn: 0.1188412	total: 11.2ms	remaining: 26ms
# 6:	learn: 0.1175713	total: 13.7ms	remaining: 25.4ms
# 7:	learn: 0.1163320	total: 15.3ms	remaining: 23ms
# 8:	learn: 0.1151282	total: 16.9ms	remaining: 20.6ms
# 9:	learn: 0.1143081	total: 18.4ms	remaining: 18.4ms
# 10:	learn: 0.1133599	total: 20.7ms	remaining: 16.9ms
# 11:	learn: 0.1127611	total: 22.1ms	remaining: 14.8ms
# 12:	learn: 0.1119622	total: 23.7ms	remaining: 12.8ms
# 13:	learn: 0.1112167	total: 25.6ms	remaining: 11ms
# 14:	learn: 0.1105725	total: 27.3ms	remaining: 9.09ms
# 15:	learn: 0.1101359	total: 29ms	remaining: 7.25ms
# 16:	learn: 0.1099048	total: 30.7ms	remaining: 5.42ms
# 17:	learn: 0.1096588	total: 32.2ms	remaining: 3.58ms
# 18:	learn: 0.1095063	total: 33.7ms	remaining: 1.77ms
# 19:	learn: 0.1091509	total: 35.5ms	remaining: 0us
# 0:	learn: 0.1265642	total: 1.84ms	remaining: 35ms
# 1:	learn: 0.1246414	total: 3.56ms	remaining: 32ms
# 2:	learn: 0.1232033	total: 5.43ms	remaining: 30.8ms
# 3:	learn: 0.1213873	total: 6.93ms	remaining: 27.7ms
# 4:	learn: 0.1198647	total: 8.45ms	remaining: 25.4ms
# 5:	learn: 0.1188570	total: 10.2ms	remaining: 23.8ms
# 6:	learn: 0.1175847	total: 11.9ms	remaining: 22.1ms
# 7:	learn: 0.1163206	total: 14.3ms	remaining: 21.5ms
# 8:	learn: 0.1150597	total: 16ms	remaining: 19.5ms
# 9:	learn: 0.1141738	total: 17.6ms	remaining: 17.6ms
# 10:	learn: 0.1134037	total: 19.2ms	remaining: 15.7ms
# 11:	learn: 0.1125315	total: 20.9ms	remaining: 13.9ms
# 12:	learn: 0.1115921	total: 22.4ms	remaining: 12ms
# 13:	learn: 0.1108875	total: 24.4ms	remaining: 10.4ms
# 14:	learn: 0.1102835	total: 26.4ms	remaining: 8.8ms
# 15:	learn: 0.1099090	total: 28.4ms	remaining: 7.09ms
# 16:	learn: 0.1096772	total: 30ms	remaining: 5.29ms
# 17:	learn: 0.1094333	total: 31.6ms	remaining: 3.51ms
# 18:	learn: 0.1092635	total: 33.2ms	remaining: 1.75ms
# 19:	learn: 0.1089047	total: 35.6ms	remaining: 0us
# 0:	learn: 0.1265356	total: 1.77ms	remaining: 33.7ms
# 1:	learn: 0.1246142	total: 4.2ms	remaining: 37.8ms
# 2:	learn: 0.1231718	total: 6.18ms	remaining: 35ms
# 3:	learn: 0.1213596	total: 8.63ms	remaining: 34.5ms
# 4:	learn: 0.1196155	total: 10.8ms	remaining: 32.3ms
# 5:	learn: 0.1186142	total: 12.6ms	remaining: 29.5ms
# 6:	learn: 0.1175093	total: 15.4ms	remaining: 28.7ms
# 7:	learn: 0.1164088	total: 17.7ms	remaining: 26.5ms
# 8:	learn: 0.1152632	total: 19.9ms	remaining: 24.4ms
# 9:	learn: 0.1142808	total: 21.8ms	remaining: 21.8ms
# 10:	learn: 0.1135035	total: 23.4ms	remaining: 19.2ms
# 11:	learn: 0.1126189	total: 25ms	remaining: 16.7ms
# 12:	learn: 0.1117438	total: 26.6ms	remaining: 14.3ms
# 13:	learn: 0.1109744	total: 28.7ms	remaining: 12.3ms
# 14:	learn: 0.1102413	total: 30.3ms	remaining: 10.1ms
# 15:	learn: 0.1098196	total: 31.8ms	remaining: 7.95ms
# 16:	learn: 0.1096801	total: 33.7ms	remaining: 5.95ms
# 17:	learn: 0.1094625	total: 35.9ms	remaining: 3.99ms
# 18:	learn: 0.1093829	total: 37.4ms	remaining: 1.97ms
# 19:	learn: 0.1090320	total: 39ms	remaining: 0us
# 0:	learn: 0.1265147	total: 1.71ms	remaining: 32.5ms
# 1:	learn: 0.1245909	total: 3.32ms	remaining: 29.9ms
# 2:	learn: 0.1231514	total: 4.97ms	remaining: 28.2ms
# 3:	learn: 0.1213381	total: 6.6ms	remaining: 26.4ms
# 4:	learn: 0.1197581	total: 8.12ms	remaining: 24.4ms
# 5:	learn: 0.1187558	total: 9.73ms	remaining: 22.7ms
# 6:	learn: 0.1174892	total: 11.5ms	remaining: 21.3ms
# 7:	learn: 0.1162391	total: 13.8ms	remaining: 20.8ms
# 8:	learn: 0.1150298	total: 15.4ms	remaining: 18.8ms
# 9:	learn: 0.1141599	total: 16.9ms	remaining: 16.9ms
# 10:	learn: 0.1132542	total: 18.6ms	remaining: 15.2ms
# 11:	learn: 0.1128057	total: 20.1ms	remaining: 13.4ms
# 12:	learn: 0.1117623	total: 21.7ms	remaining: 11.7ms
# 13:	learn: 0.1110356	total: 23.3ms	remaining: 9.97ms
# 14:	learn: 0.1103399	total: 24.9ms	remaining: 8.3ms
# 15:	learn: 0.1100046	total: 26.4ms	remaining: 6.61ms
# 16:	learn: 0.1097704	total: 28ms	remaining: 4.93ms
# 17:	learn: 0.1096317	total: 29.5ms	remaining: 3.27ms
# 18:	learn: 0.1095470	total: 31ms	remaining: 1.63ms
# 19:	learn: 0.1090748	total: 32.5ms	remaining: 0us
# 0:	learn: 0.1264898	total: 1.58ms	remaining: 30ms
# 1:	learn: 0.1245679	total: 3.27ms	remaining: 29.5ms
# 2:	learn: 0.1231275	total: 4.83ms	remaining: 27.4ms
# 3:	learn: 0.1213156	total: 6.27ms	remaining: 25.1ms
# 4:	learn: 0.1197711	total: 7.78ms	remaining: 23.3ms
# 5:	learn: 0.1187681	total: 9.91ms	remaining: 23.1ms
# 6:	learn: 0.1174968	total: 11.5ms	remaining: 21.4ms
# 7:	learn: 0.1166807	total: 13.1ms	remaining: 19.6ms
# 8:	learn: 0.1153501	total: 14.6ms	remaining: 17.9ms
# 9:	learn: 0.1142662	total: 16.1ms	remaining: 16.1ms
# 10:	learn: 0.1135112	total: 17.8ms	remaining: 14.6ms
# 11:	learn: 0.1130299	total: 19.4ms	remaining: 12.9ms
# 12:	learn: 0.1121846	total: 21ms	remaining: 11.3ms
# 13:	learn: 0.1114260	total: 22.6ms	remaining: 9.7ms
# 14:	learn: 0.1107568	total: 24.8ms	remaining: 8.27ms
# 15:	learn: 0.1103263	total: 26.5ms	remaining: 6.63ms
# 16:	learn: 0.1101017	total: 28.2ms	remaining: 4.97ms
# 17:	learn: 0.1098593	total: 29.8ms	remaining: 3.31ms
# 18:	learn: 0.1097767	total: 31.4ms	remaining: 1.65ms
# 19:	learn: 0.1090171	total: 33ms	remaining: 0us
# 0:	learn: 0.1264783	total: 1.61ms	remaining: 30.6ms
# 1:	learn: 0.1245543	total: 3.41ms	remaining: 30.7ms
# 2:	learn: 0.1231163	total: 5.1ms	remaining: 28.9ms
# 3:	learn: 0.1213032	total: 7.99ms	remaining: 32ms
# 4:	learn: 0.1197171	total: 9.54ms	remaining: 28.6ms
# 5:	learn: 0.1187149	total: 11.2ms	remaining: 26.1ms
# 6:	learn: 0.1174491	total: 12.7ms	remaining: 23.7ms
# 7:	learn: 0.1162003	total: 14.6ms	remaining: 21.9ms
# 8:	learn: 0.1149915	total: 16.8ms	remaining: 20.5ms
# 9:	learn: 0.1141208	total: 18.9ms	remaining: 18.9ms
# 10:	learn: 0.1132203	total: 20.8ms	remaining: 17.1ms
# 11:	learn: 0.1127717	total: 22.9ms	remaining: 15.3ms
# 12:	learn: 0.1117333	total: 25.5ms	remaining: 13.8ms
# 13:	learn: 0.1110066	total: 27.7ms	remaining: 11.9ms
# 14:	learn: 0.1103083	total: 29.6ms	remaining: 9.88ms
# 15:	learn: 0.1098744	total: 31.5ms	remaining: 7.87ms
# 16:	learn: 0.1096417	total: 33.6ms	remaining: 5.93ms
# 17:	learn: 0.1093998	total: 35.6ms	remaining: 3.96ms
# 18:	learn: 0.1093159	total: 37.3ms	remaining: 1.96ms
# 19:	learn: 0.1089533	total: 39.2ms	remaining: 0us
# 0:	learn: 0.1264601	total: 2.39ms	remaining: 45.3ms
# 1:	learn: 0.1245373	total: 4.1ms	remaining: 36.9ms
# 2:	learn: 0.1230985	total: 5.81ms	remaining: 32.9ms
# 3:	learn: 0.1212863	total: 7.29ms	remaining: 29.1ms
# 4:	learn: 0.1197499	total: 9.04ms	remaining: 27.1ms
# 5:	learn: 0.1187455	total: 10.7ms	remaining: 25ms
# 6:	learn: 0.1174747	total: 12.2ms	remaining: 22.7ms
# 7:	learn: 0.1162200	total: 13.7ms	remaining: 20.6ms
# 8:	learn: 0.1150115	total: 15.3ms	remaining: 18.7ms
# 9:	learn: 0.1141912	total: 16.9ms	remaining: 16.9ms
# 10:	learn: 0.1132405	total: 18.4ms	remaining: 15.1ms
# 11:	learn: 0.1126426	total: 20.1ms	remaining: 13.4ms
# 12:	learn: 0.1118605	total: 21.7ms	remaining: 11.7ms
# 13:	learn: 0.1111156	total: 23.9ms	remaining: 10.2ms
# 14:	learn: 0.1104794	total: 25.8ms	remaining: 8.61ms
# 15:	learn: 0.1100366	total: 27.7ms	remaining: 6.92ms
# 16:	learn: 0.1098048	total: 29.7ms	remaining: 5.23ms
# 17:	learn: 0.1095624	total: 31.8ms	remaining: 3.53ms
# 18:	learn: 0.1093902	total: 33.7ms	remaining: 1.77ms
# 19:	learn: 0.1089409	total: 35.4ms	remaining: 0us
# 0:	learn: 0.1264474	total: 2.24ms	remaining: 42.6ms
# 1:	learn: 0.1246680	total: 4.41ms	remaining: 39.7ms
# 2:	learn: 0.1232342	total: 6ms	remaining: 34ms
# 3:	learn: 0.1210152	total: 7.46ms	remaining: 29.8ms
# 4:	learn: 0.1192527	total: 9.03ms	remaining: 27.1ms
# 5:	learn: 0.1178879	total: 10.8ms	remaining: 25.3ms
# 6:	learn: 0.1169722	total: 12.4ms	remaining: 23.1ms
# 7:	learn: 0.1161736	total: 14ms	remaining: 21ms
# 8:	learn: 0.1151689	total: 15.6ms	remaining: 19.1ms
# 9:	learn: 0.1141650	total: 17.3ms	remaining: 17.3ms
# 10:	learn: 0.1134278	total: 18.8ms	remaining: 15.4ms
# 11:	learn: 0.1125967	total: 20.4ms	remaining: 13.6ms
# 12:	learn: 0.1119171	total: 22.1ms	remaining: 11.9ms
# 13:	learn: 0.1111460	total: 23.6ms	remaining: 10.1ms
# 14:	learn: 0.1105733	total: 25.3ms	remaining: 8.43ms
# 15:	learn: 0.1100742	total: 26.8ms	remaining: 6.69ms
# 16:	learn: 0.1098482	total: 28.3ms	remaining: 5ms
# 17:	learn: 0.1096439	total: 30.1ms	remaining: 3.34ms
# 18:	learn: 0.1094348	total: 31.6ms	remaining: 1.66ms
# 19:	learn: 0.1090815	total: 33.2ms	remaining: 0us
# 0:	learn: 0.1266840	total: 1.69ms	remaining: 32.2ms
# 1:	learn: 0.1245067	total: 4.59ms	remaining: 41.3ms
# 2:	learn: 0.1228747	total: 6.15ms	remaining: 34.9ms
# 3:	learn: 0.1208214	total: 7.66ms	remaining: 30.6ms
# 4:	learn: 0.1189777	total: 9.19ms	remaining: 27.6ms
# 5:	learn: 0.1177617	total: 10.8ms	remaining: 25.3ms
# 6:	learn: 0.1166848	total: 12.4ms	remaining: 23ms
# 7:	learn: 0.1158664	total: 14.1ms	remaining: 21.1ms
# 8:	learn: 0.1144803	total: 15.7ms	remaining: 19.2ms
# 9:	learn: 0.1135734	total: 17.3ms	remaining: 17.3ms
# 10:	learn: 0.1128257	total: 19.2ms	remaining: 15.7ms
# 11:	learn: 0.1120708	total: 20.8ms	remaining: 13.9ms
# 12:	learn: 0.1114391	total: 22.4ms	remaining: 12.1ms
# 13:	learn: 0.1107270	total: 24ms	remaining: 10.3ms
# 14:	learn: 0.1100905	total: 25.6ms	remaining: 8.53ms
# 15:	learn: 0.1097544	total: 27.2ms	remaining: 6.81ms
# 16:	learn: 0.1095239	total: 29.1ms	remaining: 5.14ms
# 17:	learn: 0.1092821	total: 30.6ms	remaining: 3.4ms
# 18:	learn: 0.1091245	total: 32.2ms	remaining: 1.69ms
# 19:	learn: 0.1087874	total: 33.8ms	remaining: 0us
# 0:	learn: 0.1266346	total: 1.71ms	remaining: 32.4ms
# 1:	learn: 0.1248488	total: 3.38ms	remaining: 30.4ms
# 2:	learn: 0.1234110	total: 5.02ms	remaining: 28.4ms
# 3:	learn: 0.1214586	total: 6.59ms	remaining: 26.4ms
# 4:	learn: 0.1196661	total: 8.74ms	remaining: 26.2ms
# 5:	learn: 0.1184187	total: 10.3ms	remaining: 24ms
# 6:	learn: 0.1174875	total: 11.9ms	remaining: 22ms
# 7:	learn: 0.1161042	total: 13.4ms	remaining: 20.1ms
# 8:	learn: 0.1153136	total: 15ms	remaining: 18.3ms
# 9:	learn: 0.1145681	total: 16.5ms	remaining: 16.5ms
# 10:	learn: 0.1137708	total: 18.1ms	remaining: 14.8ms
# 11:	learn: 0.1130003	total: 19.7ms	remaining: 13.1ms
# 12:	learn: 0.1121244	total: 21.3ms	remaining: 11.4ms
# 13:	learn: 0.1112676	total: 22.8ms	remaining: 9.79ms
# 14:	learn: 0.1106905	total: 24.3ms	remaining: 8.1ms
# 15:	learn: 0.1102184	total: 25.8ms	remaining: 6.45ms
# 16:	learn: 0.1099895	total: 27.4ms	remaining: 4.84ms
# 17:	learn: 0.1097525	total: 29ms	remaining: 3.22ms
# 18:	learn: 0.1096639	total: 30.4ms	remaining: 1.6ms
# 19:	learn: 0.1092766	total: 32ms	remaining: 0us
# 0:	learn: 0.1266359	total: 1.65ms	remaining: 31.4ms
# 1:	learn: 0.1244596	total: 3.34ms	remaining: 30ms
# 2:	learn: 0.1228282	total: 4.91ms	remaining: 27.8ms
# 3:	learn: 0.1207753	total: 6.49ms	remaining: 25.9ms
# 4:	learn: 0.1191590	total: 7.99ms	remaining: 24ms
# 5:	learn: 0.1179189	total: 9.62ms	remaining: 22.4ms
# 6:	learn: 0.1168402	total: 11.4ms	remaining: 21.1ms
# 7:	learn: 0.1160025	total: 12.9ms	remaining: 19.4ms
# 8:	learn: 0.1147278	total: 14.5ms	remaining: 17.7ms
# 9:	learn: 0.1138867	total: 16ms	remaining: 16ms
# 10:	learn: 0.1129423	total: 17.5ms	remaining: 14.3ms
# 11:	learn: 0.1121608	total: 19.1ms	remaining: 12.7ms
# 12:	learn: 0.1115193	total: 20.7ms	remaining: 11.1ms
# 13:	learn: 0.1107872	total: 22.6ms	remaining: 9.71ms
# 14:	learn: 0.1102532	total: 24.3ms	remaining: 8.09ms
# 15:	learn: 0.1097984	total: 25.7ms	remaining: 6.43ms
# 16:	learn: 0.1095697	total: 27.4ms	remaining: 4.83ms
# 17:	learn: 0.1094027	total: 28.9ms	remaining: 3.22ms
# 18:	learn: 0.1093165	total: 30.5ms	remaining: 1.6ms
# 19:	learn: 0.1089533	total: 32.1ms	remaining: 0us
# 0:	learn: 0.1266138	total: 2.13ms	remaining: 40.5ms
# 1:	learn: 0.1244378	total: 3.91ms	remaining: 35.2ms
# 2:	learn: 0.1228069	total: 5.97ms	remaining: 33.8ms
# 3:	learn: 0.1206113	total: 7.63ms	remaining: 30.5ms
# 4:	learn: 0.1188707	total: 9.14ms	remaining: 27.4ms
# 5:	learn: 0.1178193	total: 10.8ms	remaining: 25.2ms
# 6:	learn: 0.1166922	total: 13.3ms	remaining: 24.7ms
# 7:	learn: 0.1158972	total: 14.9ms	remaining: 22.3ms
# 8:	learn: 0.1144774	total: 16.3ms	remaining: 19.9ms
# 9:	learn: 0.1135897	total: 17.8ms	remaining: 17.8ms
# 10:	learn: 0.1126828	total: 19.3ms	remaining: 15.8ms
# 11:	learn: 0.1119386	total: 20.9ms	remaining: 13.9ms
# 12:	learn: 0.1112735	total: 22.3ms	remaining: 12ms
# 13:	learn: 0.1105585	total: 23.8ms	remaining: 10.2ms
# 14:	learn: 0.1099099	total: 26.3ms	remaining: 8.78ms
# 15:	learn: 0.1095724	total: 28ms	remaining: 6.99ms
# 16:	learn: 0.1093351	total: 29.6ms	remaining: 5.22ms
# 17:	learn: 0.1090826	total: 31.2ms	remaining: 3.47ms
# 18:	learn: 0.1089204	total: 32.8ms	remaining: 1.72ms
# 19:	learn: 0.1084663	total: 34.3ms	remaining: 0us
# 0:	learn: 0.1263143	total: 1.77ms	remaining: 33.6ms
# 1:	learn: 0.1245384	total: 4.19ms	remaining: 37.7ms
# 2:	learn: 0.1226500	total: 6.42ms	remaining: 36.4ms
# 3:	learn: 0.1206168	total: 8.02ms	remaining: 32.1ms
# 4:	learn: 0.1190687	total: 9.63ms	remaining: 28.9ms
# 5:	learn: 0.1178171	total: 11.3ms	remaining: 26.4ms
# 6:	learn: 0.1167814	total: 12.8ms	remaining: 23.9ms
# 7:	learn: 0.1159954	total: 14.5ms	remaining: 21.8ms
# 8:	learn: 0.1147307	total: 16.1ms	remaining: 19.7ms
# 9:	learn: 0.1138468	total: 17.6ms	remaining: 17.6ms
# 10:	learn: 0.1129124	total: 19.3ms	remaining: 15.8ms
# 11:	learn: 0.1124348	total: 20.9ms	remaining: 13.9ms
# 12:	learn: 0.1116325	total: 22.8ms	remaining: 12.3ms
# 13:	learn: 0.1109114	total: 24.6ms	remaining: 10.5ms
# 14:	learn: 0.1103140	total: 26.2ms	remaining: 8.74ms
# 15:	learn: 0.1098945	total: 28ms	remaining: 6.99ms
# 16:	learn: 0.1096722	total: 29.5ms	remaining: 5.2ms
# 17:	learn: 0.1094229	total: 31.1ms	remaining: 3.45ms
# 18:	learn: 0.1093395	total: 33.6ms	remaining: 1.77ms
# 19:	learn: 0.1088885	total: 35.4ms	remaining: 0us
# 0:	learn: 0.1265646	total: 2.14ms	remaining: 40.7ms
# 1:	learn: 0.1243900	total: 3.74ms	remaining: 33.7ms
# 2:	learn: 0.1227600	total: 5.42ms	remaining: 30.7ms
# 3:	learn: 0.1205656	total: 8.68ms	remaining: 34.7ms
# 4:	learn: 0.1187561	total: 10.3ms	remaining: 30.8ms
# 5:	learn: 0.1175717	total: 11.9ms	remaining: 27.8ms
# 6:	learn: 0.1165322	total: 13.5ms	remaining: 25ms
# 7:	learn: 0.1157316	total: 15.1ms	remaining: 22.7ms
# 8:	learn: 0.1143269	total: 16.6ms	remaining: 20.3ms
# 9:	learn: 0.1134427	total: 18.2ms	remaining: 18.2ms
# 10:	learn: 0.1125539	total: 20ms	remaining: 16.4ms
# 11:	learn: 0.1118997	total: 21.7ms	remaining: 14.4ms
# 12:	learn: 0.1112810	total: 23.3ms	remaining: 12.6ms
# 13:	learn: 0.1105810	total: 24.9ms	remaining: 10.7ms
# 14:	learn: 0.1099856	total: 26.4ms	remaining: 8.81ms
# 15:	learn: 0.1095315	total: 27.9ms	remaining: 6.98ms
# 16:	learn: 0.1093012	total: 29.5ms	remaining: 5.2ms
# 17:	learn: 0.1091309	total: 31ms	remaining: 3.45ms
# 18:	learn: 0.1090428	total: 33.2ms	remaining: 1.75ms
# 19:	learn: 0.1087098	total: 34.9ms	remaining: 0us
# 0:	learn: 0.1262638	total: 1.64ms	remaining: 31.1ms
# 1:	learn: 0.1244886	total: 3.28ms	remaining: 29.5ms
# 2:	learn: 0.1229645	total: 4.92ms	remaining: 27.9ms
# 3:	learn: 0.1207492	total: 6.41ms	remaining: 25.6ms
# 4:	learn: 0.1189825	total: 7.84ms	remaining: 23.5ms
# 5:	learn: 0.1177690	total: 9.36ms	remaining: 21.8ms
# 6:	learn: 0.1168576	total: 11ms	remaining: 20.4ms
# 7:	learn: 0.1160528	total: 12.5ms	remaining: 18.8ms
# 8:	learn: 0.1148618	total: 14.1ms	remaining: 17.2ms
# 9:	learn: 0.1141401	total: 15.6ms	remaining: 15.6ms
# 10:	learn: 0.1133634	total: 17.2ms	remaining: 14.1ms
# 11:	learn: 0.1127192	total: 18.7ms	remaining: 12.4ms
# 12:	learn: 0.1118365	total: 20.2ms	remaining: 10.9ms
# 13:	learn: 0.1109085	total: 21.7ms	remaining: 9.29ms
# 14:	learn: 0.1103369	total: 23.2ms	remaining: 7.74ms
# 15:	learn: 0.1098901	total: 24.7ms	remaining: 6.17ms
# 16:	learn: 0.1096709	total: 26.2ms	remaining: 4.62ms
# 17:	learn: 0.1094382	total: 27.8ms	remaining: 3.08ms
# 18:	learn: 0.1092557	total: 29.9ms	remaining: 1.57ms
# 19:	learn: 0.1088694	total: 32ms	remaining: 0us
# 0:	learn: 0.1265174	total: 1.7ms	remaining: 32.4ms
# 1:	learn: 0.1243436	total: 3.29ms	remaining: 29.7ms
# 2:	learn: 0.1227142	total: 4.95ms	remaining: 28.1ms
# 3:	learn: 0.1205208	total: 6.57ms	remaining: 26.3ms
# 4:	learn: 0.1188161	total: 8.56ms	remaining: 25.7ms
# 5:	learn: 0.1177645	total: 10.4ms	remaining: 24.2ms
# 6:	learn: 0.1166378	total: 12.5ms	remaining: 23.3ms
# 7:	learn: 0.1158138	total: 14.2ms	remaining: 21.3ms
# 8:	learn: 0.1146334	total: 16ms	remaining: 19.5ms
# 9:	learn: 0.1137197	total: 17.6ms	remaining: 17.6ms
# 10:	learn: 0.1127880	total: 19.5ms	remaining: 16ms
# 11:	learn: 0.1120184	total: 21.4ms	remaining: 14.3ms
# 12:	learn: 0.1113828	total: 23.4ms	remaining: 12.6ms
# 13:	learn: 0.1106837	total: 24.9ms	remaining: 10.7ms
# 14:	learn: 0.1101612	total: 26.5ms	remaining: 8.83ms
# 15:	learn: 0.1097108	total: 28ms	remaining: 7.01ms
# 16:	learn: 0.1095712	total: 29.6ms	remaining: 5.22ms
# 17:	learn: 0.1094219	total: 31.2ms	remaining: 3.47ms
# 18:	learn: 0.1093386	total: 33.2ms	remaining: 1.75ms
# 19:	learn: 0.1090010	total: 35ms	remaining: 0us
# 0:	learn: 0.1264919	total: 2.71ms	remaining: 51.5ms
# 1:	learn: 0.1243185	total: 4.3ms	remaining: 38.7ms
# 2:	learn: 0.1226896	total: 5.93ms	remaining: 33.6ms
# 3:	learn: 0.1206405	total: 8.38ms	remaining: 33.5ms
# 4:	learn: 0.1189130	total: 9.94ms	remaining: 29.8ms
# 5:	learn: 0.1176750	total: 12.4ms	remaining: 29ms
# 6:	learn: 0.1165984	total: 14.1ms	remaining: 26.1ms
# 7:	learn: 0.1157633	total: 16.3ms	remaining: 24.4ms
# 8:	learn: 0.1143610	total: 17.8ms	remaining: 21.8ms
# 9:	learn: 0.1134524	total: 19.4ms	remaining: 19.4ms
# 10:	learn: 0.1127136	total: 20.9ms	remaining: 17.1ms
# 11:	learn: 0.1120454	total: 22.4ms	remaining: 14.9ms
# 12:	learn: 0.1113816	total: 24ms	remaining: 12.9ms
# 13:	learn: 0.1106372	total: 26.1ms	remaining: 11.2ms
# 14:	learn: 0.1099508	total: 27.7ms	remaining: 9.24ms
# 15:	learn: 0.1095032	total: 29.2ms	remaining: 7.3ms
# 16:	learn: 0.1092761	total: 30.9ms	remaining: 5.45ms
# 17:	learn: 0.1090332	total: 32.5ms	remaining: 3.62ms
# 18:	learn: 0.1088774	total: 34ms	remaining: 1.79ms
# 19:	learn: 0.1081555	total: 35.7ms	remaining: 0us
# 0:	learn: 0.1269435	total: 2.08ms	remaining: 39.5ms
# 1:	learn: 0.1247479	total: 4.06ms	remaining: 36.6ms
# 2:	learn: 0.1232006	total: 6.14ms	remaining: 34.8ms
# 3:	learn: 0.1209389	total: 9.48ms	remaining: 37.9ms
# 4:	learn: 0.1191835	total: 12.3ms	remaining: 36.8ms
# 5:	learn: 0.1181063	total: 14.4ms	remaining: 33.6ms
# 6:	learn: 0.1169578	total: 16.8ms	remaining: 31.2ms
# 7:	learn: 0.1160089	total: 18.8ms	remaining: 28.2ms
# 8:	learn: 0.1145890	total: 22.2ms	remaining: 27.1ms
# 9:	learn: 0.1136786	total: 25.4ms	remaining: 25.4ms
# 10:	learn: 0.1127663	total: 28.1ms	remaining: 23ms
# 11:	learn: 0.1121082	total: 31.3ms	remaining: 20.9ms
# 12:	learn: 0.1114961	total: 34.9ms	remaining: 18.8ms
# 13:	learn: 0.1107460	total: 37.4ms	remaining: 16ms
# 14:	learn: 0.1102437	total: 39.1ms	remaining: 13ms
# 15:	learn: 0.1097904	total: 40.8ms	remaining: 10.2ms
# 16:	learn: 0.1095570	total: 42.4ms	remaining: 7.48ms
# 17:	learn: 0.1093125	total: 45.2ms	remaining: 5.02ms
# 18:	learn: 0.1091182	total: 47.9ms	remaining: 2.52ms
# 19:	learn: 0.1087446	total: 50ms	remaining: 0us
# 0:	learn: 0.1269289	total: 2.25ms	remaining: 42.8ms
# 1:	learn: 0.1247344	total: 4.72ms	remaining: 42.5ms
# 2:	learn: 0.1231876	total: 6.34ms	remaining: 35.9ms
# 3:	learn: 0.1209271	total: 7.84ms	remaining: 31.4ms
# 4:	learn: 0.1191570	total: 9.43ms	remaining: 28.3ms
# 5:	learn: 0.1180804	total: 11.1ms	remaining: 25.9ms
# 6:	learn: 0.1169318	total: 13.4ms	remaining: 24.9ms
# 7:	learn: 0.1159937	total: 14.9ms	remaining: 22.4ms
# 8:	learn: 0.1145748	total: 16.6ms	remaining: 20.2ms
# 9:	learn: 0.1136660	total: 18.3ms	remaining: 18.3ms
# 10:	learn: 0.1127532	total: 20.3ms	remaining: 16.6ms
# 11:	learn: 0.1120958	total: 21.9ms	remaining: 14.6ms
# 12:	learn: 0.1114847	total: 23.4ms	remaining: 12.6ms
# 13:	learn: 0.1107350	total: 25ms	remaining: 10.7ms
# 14:	learn: 0.1102330	total: 26.5ms	remaining: 8.84ms
# 15:	learn: 0.1097798	total: 28.3ms	remaining: 7.07ms
# 16:	learn: 0.1095465	total: 29.9ms	remaining: 5.28ms
# 17:	learn: 0.1093019	total: 31.8ms	remaining: 3.53ms
# 18:	learn: 0.1091079	total: 33.4ms	remaining: 1.76ms
# 19:	learn: 0.1087346	total: 35.1ms	remaining: 0us
# 0:	learn: 0.1261766	total: 1.68ms	remaining: 31.9ms
# 1:	learn: 0.1244055	total: 3.37ms	remaining: 30.4ms
# 2:	learn: 0.1225208	total: 5.1ms	remaining: 28.9ms
# 3:	learn: 0.1204882	total: 7.1ms	remaining: 28.4ms
# 4:	learn: 0.1189435	total: 8.85ms	remaining: 26.6ms
# 5:	learn: 0.1176558	total: 10.5ms	remaining: 24.5ms
# 6:	learn: 0.1167599	total: 12.1ms	remaining: 22.5ms
# 7:	learn: 0.1159677	total: 13.8ms	remaining: 20.7ms
# 8:	learn: 0.1146679	total: 15.5ms	remaining: 18.9ms
# 9:	learn: 0.1137502	total: 17.3ms	remaining: 17.3ms
# 10:	learn: 0.1128105	total: 19ms	remaining: 15.5ms
# 11:	learn: 0.1123332	total: 20.6ms	remaining: 13.7ms
# 12:	learn: 0.1115163	total: 22.3ms	remaining: 12ms
# 13:	learn: 0.1107835	total: 23.8ms	remaining: 10.2ms
# 14:	learn: 0.1101873	total: 25.4ms	remaining: 8.47ms
# 15:	learn: 0.1098647	total: 27ms	remaining: 6.75ms
# 16:	learn: 0.1096419	total: 28.5ms	remaining: 5.03ms
# 17:	learn: 0.1093949	total: 30.1ms	remaining: 3.34ms
# 18:	learn: 0.1091943	total: 31.9ms	remaining: 1.68ms
# 19:	learn: 0.1088200	total: 33.8ms	remaining: 0us
# 0:	learn: 0.1264192	total: 2.07ms	remaining: 39.3ms
# 1:	learn: 0.1242462	total: 3.96ms	remaining: 35.6ms
# 2:	learn: 0.1226185	total: 5.59ms	remaining: 31.7ms
# 3:	learn: 0.1204281	total: 7.29ms	remaining: 29.2ms
# 4:	learn: 0.1187030	total: 8.89ms	remaining: 26.7ms
# 5:	learn: 0.1176546	total: 10.6ms	remaining: 24.7ms
# 6:	learn: 0.1165308	total: 12.1ms	remaining: 22.5ms
# 7:	learn: 0.1157079	total: 13.8ms	remaining: 20.7ms
# 8:	learn: 0.1146424	total: 15.4ms	remaining: 18.9ms
# 9:	learn: 0.1137179	total: 17.1ms	remaining: 17.1ms
# 10:	learn: 0.1127847	total: 19.1ms	remaining: 15.7ms
# 11:	learn: 0.1120017	total: 20.7ms	remaining: 13.8ms
# 12:	learn: 0.1113661	total: 22.2ms	remaining: 12ms
# 13:	learn: 0.1105573	total: 24ms	remaining: 10.3ms
# 14:	learn: 0.1099144	total: 25.6ms	remaining: 8.53ms
# 15:	learn: 0.1095831	total: 27.2ms	remaining: 6.79ms
# 16:	learn: 0.1093591	total: 28.7ms	remaining: 5.07ms
# 17:	learn: 0.1091962	total: 31ms	remaining: 3.44ms
# 18:	learn: 0.1091122	total: 32.7ms	remaining: 1.72ms
# 19:	learn: 0.1087426	total: 34.8ms	remaining: 0us
# 0:	learn: 0.1261244	total: 2.2ms	remaining: 41.8ms
# 1:	learn: 0.1243526	total: 3.82ms	remaining: 34.4ms
# 2:	learn: 0.1224679	total: 5.41ms	remaining: 30.7ms
# 3:	learn: 0.1204379	total: 7ms	remaining: 28ms
# 4:	learn: 0.1188957	total: 8.64ms	remaining: 25.9ms
# 5:	learn: 0.1176029	total: 10.3ms	remaining: 24ms
# 6:	learn: 0.1164373	total: 11.9ms	remaining: 22.1ms
# 7:	learn: 0.1156498	total: 13.6ms	remaining: 20.4ms
# 8:	learn: 0.1143517	total: 15ms	remaining: 18.4ms
# 9:	learn: 0.1134661	total: 16.5ms	remaining: 16.5ms
# 10:	learn: 0.1125310	total: 18.1ms	remaining: 14.8ms
# 11:	learn: 0.1120835	total: 19.7ms	remaining: 13.1ms
# 12:	learn: 0.1112999	total: 21.2ms	remaining: 11.4ms
# 13:	learn: 0.1105858	total: 22.7ms	remaining: 9.75ms
# 14:	learn: 0.1100023	total: 24.3ms	remaining: 8.09ms
# 15:	learn: 0.1098419	total: 25.7ms	remaining: 6.43ms
# 16:	learn: 0.1096190	total: 27.4ms	remaining: 4.83ms
# 17:	learn: 0.1093682	total: 28.9ms	remaining: 3.21ms
# 18:	learn: 0.1092845	total: 30.4ms	remaining: 1.6ms
# 19:	learn: 0.1085504	total: 32ms	remaining: 0us
# 0:	learn: 0.1267324	total: 1.66ms	remaining: 31.5ms
# 1:	learn: 0.1246965	total: 3.97ms	remaining: 35.7ms
# 2:	learn: 0.1229385	total: 5.83ms	remaining: 33.1ms
# 3:	learn: 0.1210308	total: 7.47ms	remaining: 29.9ms
# 4:	learn: 0.1195886	total: 9.1ms	remaining: 27.3ms
# 5:	learn: 0.1182030	total: 10.8ms	remaining: 25.3ms
# 6:	learn: 0.1169597	total: 12.4ms	remaining: 23ms
# 7:	learn: 0.1158109	total: 14ms	remaining: 21ms
# 8:	learn: 0.1147789	total: 15.7ms	remaining: 19.2ms
# 9:	learn: 0.1139377	total: 17.3ms	remaining: 17.3ms
# 10:	learn: 0.1132532	total: 19.2ms	remaining: 15.7ms
# 11:	learn: 0.1126790	total: 20.9ms	remaining: 13.9ms
# 12:	learn: 0.1120034	total: 22.5ms	remaining: 12.1ms
# 13:	learn: 0.1114112	total: 24ms	remaining: 10.3ms
# 14:	learn: 0.1112495	total: 25.5ms	remaining: 8.49ms
# 15:	learn: 0.1109178	total: 27.1ms	remaining: 6.77ms
# 16:	learn: 0.1107403	total: 28.6ms	remaining: 5.05ms
# 17:	learn: 0.1105788	total: 30.5ms	remaining: 3.38ms
# 18:	learn: 0.1104641	total: 32.4ms	remaining: 1.7ms
# 19:	learn: 0.1101776	total: 34ms	remaining: 0us
# 0:	learn: 0.1266890	total: 2.35ms	remaining: 44.6ms
# 1:	learn: 0.1245477	total: 5.49ms	remaining: 49.4ms
# 2:	learn: 0.1224735	total: 8.06ms	remaining: 45.7ms
# 3:	learn: 0.1206605	total: 10.3ms	remaining: 41.1ms
# 4:	learn: 0.1192856	total: 12.7ms	remaining: 38ms
# 5:	learn: 0.1181150	total: 14.2ms	remaining: 33.2ms
# 6:	learn: 0.1172773	total: 15.9ms	remaining: 29.5ms
# 7:	learn: 0.1160166	total: 17.5ms	remaining: 26.3ms
# 8:	learn: 0.1151182	total: 19.6ms	remaining: 24ms
# 9:	learn: 0.1140048	total: 21.4ms	remaining: 21.4ms
# 10:	learn: 0.1128055	total: 23.1ms	remaining: 18.9ms
# 11:	learn: 0.1125189	total: 25.2ms	remaining: 16.8ms
# 12:	learn: 0.1120424	total: 26.9ms	remaining: 14.5ms
# 13:	learn: 0.1115985	total: 28.6ms	remaining: 12.2ms
# 14:	learn: 0.1112825	total: 30.3ms	remaining: 10.1ms
# 15:	learn: 0.1108475	total: 32ms	remaining: 8ms
# 16:	learn: 0.1102253	total: 33.8ms	remaining: 5.96ms
# 17:	learn: 0.1100650	total: 35.4ms	remaining: 3.93ms
# 18:	learn: 0.1093279	total: 37ms	remaining: 1.95ms
# 19:	learn: 0.1091617	total: 38.8ms	remaining: 0us
# 0:	learn: 0.1267025	total: 2.33ms	remaining: 44.3ms
# 1:	learn: 0.1245593	total: 4.04ms	remaining: 36.3ms
# 2:	learn: 0.1228371	total: 5.62ms	remaining: 31.9ms
# 3:	learn: 0.1209541	total: 7.43ms	remaining: 29.7ms
# 4:	learn: 0.1195635	total: 9.44ms	remaining: 28.3ms
# 5:	learn: 0.1182218	total: 11.4ms	remaining: 26.5ms
# 6:	learn: 0.1165740	total: 13.2ms	remaining: 24.5ms
# 7:	learn: 0.1155227	total: 15.1ms	remaining: 22.7ms
# 8:	learn: 0.1146210	total: 16.8ms	remaining: 20.6ms
# 9:	learn: 0.1136271	total: 18.4ms	remaining: 18.4ms
# 10:	learn: 0.1126709	total: 21.2ms	remaining: 17.3ms
# 11:	learn: 0.1124071	total: 23.4ms	remaining: 15.6ms
# 12:	learn: 0.1116050	total: 25.9ms	remaining: 14ms
# 13:	learn: 0.1110484	total: 27.6ms	remaining: 11.8ms
# 14:	learn: 0.1105034	total: 29.2ms	remaining: 9.72ms
# 15:	learn: 0.1100302	total: 30.9ms	remaining: 7.73ms
# 16:	learn: 0.1096146	total: 32.5ms	remaining: 5.74ms
# 17:	learn: 0.1094392	total: 35.1ms	remaining: 3.9ms
# 18:	learn: 0.1087855	total: 37.1ms	remaining: 1.95ms
# 19:	learn: 0.1084873	total: 39ms	remaining: 0us
# 0:	learn: 0.1265018	total: 2.7ms	remaining: 51.3ms
# 1:	learn: 0.1243822	total: 4.69ms	remaining: 42.2ms
# 2:	learn: 0.1227186	total: 6.48ms	remaining: 36.7ms
# 3:	learn: 0.1209470	total: 8.01ms	remaining: 32.1ms
# 4:	learn: 0.1195696	total: 9.63ms	remaining: 28.9ms
# 5:	learn: 0.1183048	total: 11.6ms	remaining: 27ms
# 6:	learn: 0.1169279	total: 13.6ms	remaining: 25.2ms
# 7:	learn: 0.1159500	total: 15.6ms	remaining: 23.4ms
# 8:	learn: 0.1150538	total: 17.5ms	remaining: 21.4ms
# 9:	learn: 0.1142360	total: 19ms	remaining: 19ms
# 10:	learn: 0.1136492	total: 20.7ms	remaining: 16.9ms
# 11:	learn: 0.1132421	total: 22.1ms	remaining: 14.8ms
# 12:	learn: 0.1124433	total: 23.7ms	remaining: 12.8ms
# 13:	learn: 0.1121439	total: 26ms	remaining: 11.1ms
# 14:	learn: 0.1115743	total: 27.8ms	remaining: 9.27ms
# 15:	learn: 0.1110747	total: 29.7ms	remaining: 7.41ms
# 16:	learn: 0.1104443	total: 31.4ms	remaining: 5.54ms
# 17:	learn: 0.1102873	total: 32.9ms	remaining: 3.66ms
# 18:	learn: 0.1096478	total: 34.6ms	remaining: 1.82ms
# 19:	learn: 0.1094819	total: 36.2ms	remaining: 0us
# 0:	learn: 0.1264775	total: 2.25ms	remaining: 42.7ms
# 1:	learn: 0.1243580	total: 4.23ms	remaining: 38.1ms
# 2:	learn: 0.1227008	total: 5.88ms	remaining: 33.3ms
# 3:	learn: 0.1209294	total: 7.54ms	remaining: 30.2ms
# 4:	learn: 0.1195523	total: 9.18ms	remaining: 27.5ms
# 5:	learn: 0.1182876	total: 10.8ms	remaining: 25.2ms
# 6:	learn: 0.1166414	total: 12.3ms	remaining: 22.8ms
# 7:	learn: 0.1157487	total: 13.8ms	remaining: 20.7ms
# 8:	learn: 0.1148270	total: 15.4ms	remaining: 18.8ms
# 9:	learn: 0.1138561	total: 17ms	remaining: 17ms
# 10:	learn: 0.1127889	total: 18.8ms	remaining: 15.4ms
# 11:	learn: 0.1124866	total: 20.3ms	remaining: 13.5ms
# 12:	learn: 0.1116271	total: 21.9ms	remaining: 11.8ms
# 13:	learn: 0.1109244	total: 23.5ms	remaining: 10.1ms
# 14:	learn: 0.1106036	total: 25.2ms	remaining: 8.39ms
# 15:	learn: 0.1101507	total: 26.8ms	remaining: 6.71ms
# 16:	learn: 0.1096552	total: 28.5ms	remaining: 5.03ms
# 17:	learn: 0.1094801	total: 30ms	remaining: 3.34ms
# 18:	learn: 0.1087466	total: 31.8ms	remaining: 1.67ms
# 19:	learn: 0.1083404	total: 33.6ms	remaining: 0us
# 0:	learn: 0.1264529	total: 2.22ms	remaining: 42.3ms
# 1:	learn: 0.1243341	total: 3.91ms	remaining: 35.2ms
# 2:	learn: 0.1227627	total: 5.46ms	remaining: 30.9ms
# 3:	learn: 0.1210359	total: 7.15ms	remaining: 28.6ms
# 4:	learn: 0.1196357	total: 8.68ms	remaining: 26ms
# 5:	learn: 0.1181010	total: 10.2ms	remaining: 23.7ms
# 6:	learn: 0.1164624	total: 11.6ms	remaining: 21.6ms
# 7:	learn: 0.1154439	total: 13.1ms	remaining: 19.7ms
# 8:	learn: 0.1145299	total: 14.7ms	remaining: 17.9ms
# 9:	learn: 0.1133940	total: 16.1ms	remaining: 16.1ms
# 10:	learn: 0.1123472	total: 17.8ms	remaining: 14.5ms
# 11:	learn: 0.1120821	total: 19.2ms	remaining: 12.8ms
# 12:	learn: 0.1113163	total: 21ms	remaining: 11.3ms
# 13:	learn: 0.1107102	total: 22.6ms	remaining: 9.67ms
# 14:	learn: 0.1103595	total: 24.2ms	remaining: 8.05ms
# 15:	learn: 0.1099151	total: 25.7ms	remaining: 6.42ms
# 16:	learn: 0.1094506	total: 27.3ms	remaining: 4.82ms
# 17:	learn: 0.1092998	total: 29ms	remaining: 3.22ms
# 18:	learn: 0.1086907	total: 30.6ms	remaining: 1.61ms
# 19:	learn: 0.1082980	total: 32.1ms	remaining: 0us
# 0:	learn: 0.1266209	total: 1.76ms	remaining: 33.4ms
# 1:	learn: 0.1241845	total: 3.37ms	remaining: 30.3ms
# 2:	learn: 0.1222793	total: 4.89ms	remaining: 27.7ms
# 3:	learn: 0.1211147	total: 6.46ms	remaining: 25.8ms
# 4:	learn: 0.1193592	total: 8.04ms	remaining: 24.1ms
# 5:	learn: 0.1181486	total: 10.2ms	remaining: 23.9ms
# 6:	learn: 0.1169037	total: 11.8ms	remaining: 22ms
# 7:	learn: 0.1154351	total: 13.9ms	remaining: 20.8ms
# 8:	learn: 0.1142880	total: 15.4ms	remaining: 18.9ms
# 9:	learn: 0.1134416	total: 17.1ms	remaining: 17.1ms
# 10:	learn: 0.1127660	total: 18.8ms	remaining: 15.3ms
# 11:	learn: 0.1119935	total: 20.3ms	remaining: 13.5ms
# 12:	learn: 0.1112820	total: 21.9ms	remaining: 11.8ms
# 13:	learn: 0.1105280	total: 23.5ms	remaining: 10.1ms
# 14:	learn: 0.1102668	total: 25ms	remaining: 8.33ms
# 15:	learn: 0.1100066	total: 26.5ms	remaining: 6.63ms
# 16:	learn: 0.1098769	total: 28.1ms	remaining: 4.96ms
# 17:	learn: 0.1097900	total: 29.7ms	remaining: 3.3ms
# 18:	learn: 0.1096769	total: 31.3ms	remaining: 1.65ms
# 19:	learn: 0.1090512	total: 32.8ms	remaining: 0us
# 0:	learn: 0.1265987	total: 1.78ms	remaining: 33.8ms
# 1:	learn: 0.1243322	total: 3.37ms	remaining: 30.3ms
# 2:	learn: 0.1222249	total: 4.97ms	remaining: 28.2ms
# 3:	learn: 0.1204775	total: 6.51ms	remaining: 26ms
# 4:	learn: 0.1189596	total: 7.98ms	remaining: 24ms
# 5:	learn: 0.1177969	total: 9.53ms	remaining: 22.2ms
# 6:	learn: 0.1164972	total: 11.1ms	remaining: 20.5ms
# 7:	learn: 0.1151224	total: 12.5ms	remaining: 18.8ms
# 8:	learn: 0.1137443	total: 14.2ms	remaining: 17.3ms
# 9:	learn: 0.1128136	total: 15.9ms	remaining: 15.9ms
# 10:	learn: 0.1121772	total: 17.7ms	remaining: 14.5ms
# 11:	learn: 0.1111557	total: 19.4ms	remaining: 13ms
# 12:	learn: 0.1105246	total: 21.1ms	remaining: 11.4ms
# 13:	learn: 0.1103550	total: 22.8ms	remaining: 9.75ms
# 14:	learn: 0.1101019	total: 24.3ms	remaining: 8.1ms
# 15:	learn: 0.1099372	total: 25.6ms	remaining: 6.41ms
# 16:	learn: 0.1097307	total: 27.3ms	remaining: 4.82ms
# 17:	learn: 0.1093692	total: 28.9ms	remaining: 3.21ms
# 18:	learn: 0.1088209	total: 30.4ms	remaining: 1.6ms
# 19:	learn: 0.1084519	total: 31.9ms	remaining: 0us
# 0:	learn: 0.1266595	total: 1.99ms	remaining: 37.7ms
# 1:	learn: 0.1239195	total: 3.57ms	remaining: 32.1ms
# 2:	learn: 0.1217577	total: 5.88ms	remaining: 33.4ms
# ...
# 13:	learn: 0.0700934	total: 19.1ms	remaining: 8.17ms
# 14:	learn: 0.0695137	total: 20.5ms	remaining: 6.84ms
# 15:	learn: 0.0691217	total: 21.9ms	remaining: 5.47ms
# 16:	learn: 0.0689266	total: 23.1ms	remaining: 4.07ms
# 17:	learn: 0.0686877	total: 24.2ms	remaining: 2.69ms
# 18:	learn: 0.0684942	total: 25.5ms	remaining: 1.34ms
# 19:	learn: 0.0683072	total: 26.7ms	remaining: 0us
# 0:	learn: 0.0775144	total: 2.05ms	remaining: 39ms
# 1:	learn: 0.0764906	total: 3.63ms	remaining: 32.6ms
# 2:	learn: 0.0755969	total: 4.93ms	remaining: 28ms
# 3:	learn: 0.0745934	total: 6.31ms	remaining: 25.2ms
# 4:	learn: 0.0738613	total: 7.55ms	remaining: 22.6ms
# 5:	learn: 0.0731308	total: 9.78ms	remaining: 22.8ms
# 6:	learn: 0.0729104	total: 11.3ms	remaining: 20.9ms
# 7:	learn: 0.0726224	total: 12.8ms	remaining: 19.2ms
# 8:	learn: 0.0720943	total: 14.2ms	remaining: 17.4ms
# 9:	learn: 0.0718611	total: 15.5ms	remaining: 15.5ms
# 10:	learn: 0.0712614	total: 16.8ms	remaining: 13.7ms
# 11:	learn: 0.0710355	total: 18ms	remaining: 12ms
# 12:	learn: 0.0704454	total: 19.4ms	remaining: 10.4ms
# 13:	learn: 0.0701987	total: 20.6ms	remaining: 8.82ms
# 14:	learn: 0.0696193	total: 21.9ms	remaining: 7.31ms
# 15:	learn: 0.0692286	total: 23.1ms	remaining: 5.79ms
# 16:	learn: 0.0690340	total: 24.3ms	remaining: 4.29ms
# 17:	learn: 0.0687869	total: 25.5ms	remaining: 2.84ms
# 18:	learn: 0.0685938	total: 26.8ms	remaining: 1.41ms
# 19:	learn: 0.0684071	total: 28ms	remaining: 0us
# 0:	learn: 0.0775113	total: 2.07ms	remaining: 39.4ms
# 1:	learn: 0.0764838	total: 3.56ms	remaining: 32.1ms
# 2:	learn: 0.0755889	total: 4.81ms	remaining: 27.3ms
# 3:	learn: 0.0745835	total: 6.94ms	remaining: 27.8ms
# 4:	learn: 0.0738528	total: 8.24ms	remaining: 24.7ms
# 5:	learn: 0.0731216	total: 9.55ms	remaining: 22.3ms
# 6:	learn: 0.0729013	total: 10.8ms	remaining: 20ms
# 7:	learn: 0.0726134	total: 12.1ms	remaining: 18.2ms
# 8:	learn: 0.0720839	total: 13.5ms	remaining: 16.5ms
# 9:	learn: 0.0718509	total: 14.9ms	remaining: 14.9ms
# 10:	learn: 0.0712503	total: 16.2ms	remaining: 13.2ms
# 11:	learn: 0.0710245	total: 17.4ms	remaining: 11.6ms
# 12:	learn: 0.0704336	total: 18.6ms	remaining: 10ms
# 13:	learn: 0.0701870	total: 19.9ms	remaining: 8.53ms
# 14:	learn: 0.0696066	total: 21.2ms	remaining: 7.07ms
# 15:	learn: 0.0692157	total: 22.5ms	remaining: 5.62ms
# 16:	learn: 0.0690211	total: 23.8ms	remaining: 4.2ms
# 17:	learn: 0.0687740	total: 25.1ms	remaining: 2.79ms
# 18:	learn: 0.0685811	total: 26.3ms	remaining: 1.38ms
# 19:	learn: 0.0683944	total: 27.5ms	remaining: 0us
# 0:	learn: 0.0775180	total: 2.31ms	remaining: 43.9ms
# 1:	learn: 0.0764900	total: 3.73ms	remaining: 33.6ms
# 2:	learn: 0.0755946	total: 5.08ms	remaining: 28.8ms
# 3:	learn: 0.0745879	total: 6.44ms	remaining: 25.8ms
# 4:	learn: 0.0738561	total: 8.91ms	remaining: 26.7ms
# 5:	learn: 0.0731247	total: 11.4ms	remaining: 26.6ms
# 6:	learn: 0.0729044	total: 12.8ms	remaining: 23.8ms
# 7:	learn: 0.0726166	total: 14.4ms	remaining: 21.6ms
# 8:	learn: 0.0720862	total: 15.8ms	remaining: 19.3ms
# 9:	learn: 0.0718533	total: 17.2ms	remaining: 17.2ms
# 10:	learn: 0.0712524	total: 18.7ms	remaining: 15.3ms
# 11:	learn: 0.0710267	total: 20.2ms	remaining: 13.5ms
# 12:	learn: 0.0704355	total: 21.7ms	remaining: 11.7ms
# 13:	learn: 0.0701889	total: 23ms	remaining: 9.86ms
# 14:	learn: 0.0696079	total: 24.4ms	remaining: 8.13ms
# 15:	learn: 0.0691446	total: 25.8ms	remaining: 6.45ms
# 16:	learn: 0.0689739	total: 27.1ms	remaining: 4.79ms
# 17:	learn: 0.0687991	total: 28.4ms	remaining: 3.16ms
# 18:	learn: 0.0686060	total: 29.7ms	remaining: 1.56ms
# 19:	learn: 0.0682067	total: 30.9ms	remaining: 0us
# 0:	learn: 0.0775143	total: 1.41ms	remaining: 26.7ms
# 1:	learn: 0.0764898	total: 2.88ms	remaining: 25.9ms
# 2:	learn: 0.0755955	total: 4.25ms	remaining: 24.1ms
# 3:	learn: 0.0745902	total: 5.62ms	remaining: 22.5ms
# 4:	learn: 0.0738591	total: 6.89ms	remaining: 20.7ms
# 5:	learn: 0.0731276	total: 8.27ms	remaining: 19.3ms
# 6:	learn: 0.0729074	total: 9.56ms	remaining: 17.8ms
# 7:	learn: 0.0726197	total: 10.9ms	remaining: 16.3ms
# 8:	learn: 0.0720901	total: 12.2ms	remaining: 14.9ms
# 9:	learn: 0.0718572	total: 13.5ms	remaining: 13.5ms
# 10:	learn: 0.0712569	total: 14.7ms	remaining: 12.1ms
# 11:	learn: 0.0710312	total: 16ms	remaining: 10.7ms
# 12:	learn: 0.0704405	total: 17.3ms	remaining: 9.32ms
# 13:	learn: 0.0701940	total: 18.6ms	remaining: 7.97ms
# 14:	learn: 0.0696137	total: 19.9ms	remaining: 6.65ms
# 15:	learn: 0.0692184	total: 21.2ms	remaining: 5.29ms
# 16:	learn: 0.0690240	total: 22.4ms	remaining: 3.96ms
# 17:	learn: 0.0687768	total: 23.7ms	remaining: 2.63ms
# 18:	learn: 0.0685840	total: 24.9ms	remaining: 1.31ms
# 19:	learn: 0.0683975	total: 26.1ms	remaining: 0us
# 0:	learn: 0.0775084	total: 1.43ms	remaining: 27.3ms
# 1:	learn: 0.0764835	total: 2.88ms	remaining: 25.9ms
# 2:	learn: 0.0755907	total: 4.13ms	remaining: 23.4ms
# 3:	learn: 0.0745849	total: 5.41ms	remaining: 21.7ms
# 4:	learn: 0.0738535	total: 6.7ms	remaining: 20.1ms
# 5:	learn: 0.0731229	total: 7.94ms	remaining: 18.5ms
# 6:	learn: 0.0729028	total: 9.99ms	remaining: 18.6ms
# 7:	learn: 0.0726152	total: 11.3ms	remaining: 17ms
# 8:	learn: 0.0720853	total: 12.5ms	remaining: 15.3ms
# 9:	learn: 0.0718525	total: 13.8ms	remaining: 13.8ms
# 10:	learn: 0.0712521	total: 15ms	remaining: 12.3ms
# 11:	learn: 0.0710265	total: 16.3ms	remaining: 10.8ms
# 12:	learn: 0.0704358	total: 17.5ms	remaining: 9.43ms
# 13:	learn: 0.0701894	total: 18.8ms	remaining: 8.05ms
# 14:	learn: 0.0696090	total: 20.7ms	remaining: 6.91ms
# 15:	learn: 0.0691461	total: 22ms	remaining: 5.49ms
# 16:	learn: 0.0689756	total: 23.1ms	remaining: 4.08ms
# 17:	learn: 0.0688007	total: 24.4ms	remaining: 2.71ms
# 18:	learn: 0.0686063	total: 25.6ms	remaining: 1.34ms
# 19:	learn: 0.0682075	total: 27ms	remaining: 0us
# 0:	learn: 0.0775097	total: 1.39ms	remaining: 26.5ms
# 1:	learn: 0.0764856	total: 2.86ms	remaining: 25.8ms
# 2:	learn: 0.0755935	total: 4.18ms	remaining: 23.7ms
# 3:	learn: 0.0745886	total: 5.49ms	remaining: 22ms
# 4:	learn: 0.0738578	total: 6.93ms	remaining: 20.8ms
# 5:	learn: 0.0731268	total: 8.18ms	remaining: 19.1ms
# 6:	learn: 0.0729068	total: 9.38ms	remaining: 17.4ms
# 7:	learn: 0.0726193	total: 11.5ms	remaining: 17.2ms
# 8:	learn: 0.0720901	total: 14.3ms	remaining: 17.4ms
# 9:	learn: 0.0718574	total: 15.5ms	remaining: 15.5ms
# 10:	learn: 0.0712571	total: 16.8ms	remaining: 13.7ms
# 11:	learn: 0.0710317	total: 18ms	remaining: 12ms
# 12:	learn: 0.0704412	total: 19.3ms	remaining: 10.4ms
# 13:	learn: 0.0701949	total: 20.5ms	remaining: 8.77ms
# 14:	learn: 0.0696150	total: 21.9ms	remaining: 7.29ms
# 15:	learn: 0.0691524	total: 23.2ms	remaining: 5.79ms
# 16:	learn: 0.0689819	total: 24.4ms	remaining: 4.31ms
# 17:	learn: 0.0688070	total: 25.7ms	remaining: 2.85ms
# 18:	learn: 0.0686129	total: 27ms	remaining: 1.42ms
# 19:	learn: 0.0682134	total: 28.2ms	remaining: 0us
# 0:	learn: 0.0774894	total: 1.26ms	remaining: 23.9ms
# 1:	learn: 0.0764640	total: 2.72ms	remaining: 24.5ms
# 2:	learn: 0.0755736	total: 4ms	remaining: 22.7ms
# 3:	learn: 0.0745703	total: 5.35ms	remaining: 21.4ms
# 4:	learn: 0.0738407	total: 6.62ms	remaining: 19.8ms
# 5:	learn: 0.0731096	total: 7.92ms	remaining: 18.5ms
# 6:	learn: 0.0728896	total: 9.29ms	remaining: 17.2ms
# 7:	learn: 0.0726021	total: 10.6ms	remaining: 16ms
# 8:	learn: 0.0720735	total: 12ms	remaining: 14.7ms
# 9:	learn: 0.0718408	total: 13.2ms	remaining: 13.2ms
# 10:	learn: 0.0712415	total: 14.5ms	remaining: 11.8ms
# 11:	learn: 0.0710160	total: 15.7ms	remaining: 10.5ms
# 12:	learn: 0.0704261	total: 17.1ms	remaining: 9.18ms
# 13:	learn: 0.0701798	total: 18.3ms	remaining: 7.83ms
# 14:	learn: 0.0696006	total: 19.6ms	remaining: 6.54ms
# 15:	learn: 0.0691384	total: 20.9ms	remaining: 5.23ms
# 16:	learn: 0.0689679	total: 22.1ms	remaining: 3.9ms
# 17:	learn: 0.0688079	total: 23.4ms	remaining: 2.6ms
# 18:	learn: 0.0686137	total: 24.5ms	remaining: 1.29ms
# 19:	learn: 0.0682140	total: 25.9ms	remaining: 0us
# 0:	learn: 0.0774869	total: 2.14ms	remaining: 40.7ms
# 1:	learn: 0.0764608	total: 3.55ms	remaining: 32ms
# 2:	learn: 0.0755709	total: 5.85ms	remaining: 33.1ms
# 3:	learn: 0.0745683	total: 7.39ms	remaining: 29.6ms
# 4:	learn: 0.0738390	total: 8.74ms	remaining: 26.2ms
# 5:	learn: 0.0731077	total: 10ms	remaining: 23.4ms
# 6:	learn: 0.0728877	total: 11.2ms	remaining: 20.8ms
# 7:	learn: 0.0726004	total: 12.4ms	remaining: 18.7ms
# 8:	learn: 0.0720722	total: 13.7ms	remaining: 16.8ms
# 9:	learn: 0.0718396	total: 15ms	remaining: 15ms
# 10:	learn: 0.0712404	total: 16.3ms	remaining: 13.3ms
# 11:	learn: 0.0710150	total: 17.5ms	remaining: 11.7ms
# 12:	learn: 0.0704253	total: 18.7ms	remaining: 10.1ms
# 13:	learn: 0.0701792	total: 19.9ms	remaining: 8.54ms
# 14:	learn: 0.0696599	total: 21.3ms	remaining: 7.11ms
# 15:	learn: 0.0694592	total: 22.6ms	remaining: 5.65ms
# 16:	learn: 0.0692620	total: 23.8ms	remaining: 4.2ms
# 17:	learn: 0.0690392	total: 25ms	remaining: 2.78ms
# 18:	learn: 0.0688434	total: 26.3ms	remaining: 1.38ms
# 19:	learn: 0.0686950	total: 27.5ms	remaining: 0us
# 0:	learn: 0.0774895	total: 1.41ms	remaining: 26.7ms
# 1:	learn: 0.0764629	total: 2.8ms	remaining: 25.2ms
# 2:	learn: 0.0755724	total: 4.08ms	remaining: 23.2ms
# 3:	learn: 0.0745686	total: 5.58ms	remaining: 22.3ms
# 4:	learn: 0.0738384	total: 6.83ms	remaining: 20.5ms
# 5:	learn: 0.0731068	total: 8.08ms	remaining: 18.9ms
# 6:	learn: 0.0728869	total: 9.25ms	remaining: 17.2ms
# 7:	learn: 0.0725996	total: 10.6ms	remaining: 15.8ms
# 8:	learn: 0.0720705	total: 12.5ms	remaining: 15.3ms
# 9:	learn: 0.0718380	total: 13.9ms	remaining: 13.9ms
# 10:	learn: 0.0712385	total: 15.1ms	remaining: 12.4ms
# 11:	learn: 0.0710132	total: 16.4ms	remaining: 10.9ms
# 12:	learn: 0.0704232	total: 17.6ms	remaining: 9.48ms
# 13:	learn: 0.0701770	total: 18.9ms	remaining: 8.1ms
# 14:	learn: 0.0696570	total: 20.2ms	remaining: 6.74ms
# 15:	learn: 0.0694564	total: 21.6ms	remaining: 5.41ms
# 16:	learn: 0.0692593	total: 22.9ms	remaining: 4.05ms
# 17:	learn: 0.0691262	total: 24.2ms	remaining: 2.69ms
# 18:	learn: 0.0689307	total: 25.5ms	remaining: 1.34ms
# 19:	learn: 0.0685131	total: 26.8ms	remaining: 0us
# 0:	learn: 0.0774943	total: 2.03ms	remaining: 38.5ms
# 1:	learn: 0.0764651	total: 3.46ms	remaining: 31.2ms
# 2:	learn: 0.0755735	total: 4.7ms	remaining: 26.6ms
# 3:	learn: 0.0745683	total: 6.05ms	remaining: 24.2ms
# 4:	learn: 0.0738367	total: 7.3ms	remaining: 21.9ms
# 5:	learn: 0.0731052	total: 8.72ms	remaining: 20.3ms
# 6:	learn: 0.0728853	total: 9.89ms	remaining: 18.4ms
# 7:	learn: 0.0725981	total: 11.9ms	remaining: 17.9ms
# 8:	learn: 0.0720684	total: 13.3ms	remaining: 16.2ms
# 9:	learn: 0.0718359	total: 14.5ms	remaining: 14.5ms
# 10:	learn: 0.0712358	total: 15.9ms	remaining: 13ms
# 11:	learn: 0.0710105	total: 17.2ms	remaining: 11.5ms
# 12:	learn: 0.0704202	total: 18.5ms	remaining: 9.95ms
# 13:	learn: 0.0701740	total: 19.7ms	remaining: 8.46ms
# 14:	learn: 0.0696535	total: 21.1ms	remaining: 7.02ms
# 15:	learn: 0.0694530	total: 22.4ms	remaining: 5.59ms
# 16:	learn: 0.0692559	total: 23.7ms	remaining: 4.18ms
# 17:	learn: 0.0691228	total: 24.9ms	remaining: 2.77ms
# 18:	learn: 0.0689273	total: 26.1ms	remaining: 1.37ms
# 19:	learn: 0.0685095	total: 27.3ms	remaining: 0us
# 0:	learn: 0.0774936	total: 2.04ms	remaining: 38.8ms
# 1:	learn: 0.0764656	total: 3.49ms	remaining: 31.4ms
# 2:	learn: 0.0755734	total: 4.82ms	remaining: 27.3ms
# 3:	learn: 0.0746296	total: 6.22ms	remaining: 24.9ms
# 4:	learn: 0.0738928	total: 7.55ms	remaining: 22.6ms
# 5:	learn: 0.0731521	total: 8.87ms	remaining: 20.7ms
# 6:	learn: 0.0729346	total: 10ms	remaining: 18.6ms
# 7:	learn: 0.0726450	total: 11.3ms	remaining: 16.9ms
# 8:	learn: 0.0721117	total: 12.7ms	remaining: 15.5ms
# 9:	learn: 0.0718772	total: 13.9ms	remaining: 13.9ms
# 10:	learn: 0.0712700	total: 15.1ms	remaining: 12.4ms
# 11:	learn: 0.0710429	total: 16.4ms	remaining: 10.9ms
# 12:	learn: 0.0704451	total: 17.8ms	remaining: 9.56ms
# 13:	learn: 0.0701959	total: 19ms	remaining: 8.16ms
# 14:	learn: 0.0696705	total: 20.2ms	remaining: 6.75ms
# 15:	learn: 0.0694683	total: 21.5ms	remaining: 5.37ms
# 16:	learn: 0.0692714	total: 22.8ms	remaining: 4.03ms
# 17:	learn: 0.0690869	total: 24.1ms	remaining: 2.68ms
# 18:	learn: 0.0688913	total: 25.3ms	remaining: 1.33ms
# 19:	learn: 0.0684725	total: 26.6ms	remaining: 0us
# 0:	learn: 0.0774948	total: 1.28ms	remaining: 24.4ms
# 1:	learn: 0.0764684	total: 2.61ms	remaining: 23.5ms
# 2:	learn: 0.0755398	total: 3.91ms	remaining: 22.1ms
# 3:	learn: 0.0746043	total: 6.12ms	remaining: 24.5ms
# 4:	learn: 0.0739359	total: 7.49ms	remaining: 22.5ms
# 5:	learn: 0.0731945	total: 8.74ms	remaining: 20.4ms
# 6:	learn: 0.0729768	total: 9.94ms	remaining: 18.5ms
# 7:	learn: 0.0726896	total: 11.2ms	remaining: 16.8ms
# 8:	learn: 0.0721148	total: 12.5ms	remaining: 15.3ms
# 9:	learn: 0.0718854	total: 13.9ms	remaining: 13.9ms
# 10:	learn: 0.0713254	total: 15.3ms	remaining: 12.5ms
# 11:	learn: 0.0711046	total: 16.6ms	remaining: 11.1ms
# 12:	learn: 0.0704975	total: 17.8ms	remaining: 9.58ms
# 13:	learn: 0.0703622	total: 19ms	remaining: 8.13ms
# 14:	learn: 0.0698244	total: 20.3ms	remaining: 6.77ms
# 15:	learn: 0.0695073	total: 21.7ms	remaining: 5.42ms
# 16:	learn: 0.0693384	total: 22.9ms	remaining: 4.04ms
# 17:	learn: 0.0689831	total: 24.3ms	remaining: 2.7ms
# 18:	learn: 0.0687798	total: 25.6ms	remaining: 1.35ms
# 19:	learn: 0.0683812	total: 26.9ms	remaining: 0us
# 0:	learn: 0.0774910	total: 1.33ms	remaining: 25.4ms
# 1:	learn: 0.0764638	total: 2.67ms	remaining: 24.1ms
# 2:	learn: 0.0755725	total: 3.98ms	remaining: 22.5ms
# 3:	learn: 0.0746289	total: 5.32ms	remaining: 21.3ms
# 4:	learn: 0.0739549	total: 6.66ms	remaining: 20ms
# 5:	learn: 0.0732072	total: 7.95ms	remaining: 18.6ms
# 6:	learn: 0.0729841	total: 9.14ms	remaining: 17ms
# 7:	learn: 0.0726917	total: 10.4ms	remaining: 15.6ms
# 8:	learn: 0.0721127	total: 11.7ms	remaining: 14.3ms
# 9:	learn: 0.0718786	total: 13ms	remaining: 13ms
# 10:	learn: 0.0712870	total: 14.2ms	remaining: 11.6ms
# 11:	learn: 0.0710618	total: 15.5ms	remaining: 10.3ms
# 12:	learn: 0.0704571	total: 16.8ms	remaining: 9.03ms
# 13:	learn: 0.0702107	total: 18ms	remaining: 7.72ms
# 14:	learn: 0.0696799	total: 19.3ms	remaining: 6.44ms
# 15:	learn: 0.0693786	total: 20.6ms	remaining: 5.14ms
# 16:	learn: 0.0691802	total: 21.8ms	remaining: 3.85ms
# 17:	learn: 0.0688172	total: 23.1ms	remaining: 2.56ms
# 18:	learn: 0.0686180	total: 24.2ms	remaining: 1.27ms
# 19:	learn: 0.0682246	total: 25.8ms	remaining: 0us
# 0:	learn: 0.0774888	total: 1.44ms	remaining: 27.4ms
# 1:	learn: 0.0764593	total: 2.9ms	remaining: 26.1ms
# 2:	learn: 0.0755290	total: 4.25ms	remaining: 24.1ms
# 3:	learn: 0.0745952	total: 5.58ms	remaining: 22.3ms
# 4:	learn: 0.0738597	total: 6.84ms	remaining: 20.5ms
# 5:	learn: 0.0731227	total: 8.08ms	remaining: 18.8ms
# 6:	learn: 0.0729057	total: 9.25ms	remaining: 17.2ms
# 7:	learn: 0.0726208	total: 10.5ms	remaining: 15.8ms
# 8:	learn: 0.0720495	total: 11.8ms	remaining: 14.4ms
# 9:	learn: 0.0718219	total: 13ms	remaining: 13ms
# 10:	learn: 0.0711842	total: 14.3ms	remaining: 11.7ms
# 11:	learn: 0.0709640	total: 15.7ms	remaining: 10.4ms
# 12:	learn: 0.0703692	total: 16.9ms	remaining: 9.11ms
# 13:	learn: 0.0702339	total: 18.1ms	remaining: 7.77ms
# 14:	learn: 0.0697739	total: 19.5ms	remaining: 6.5ms
# 15:	learn: 0.0694588	total: 20.8ms	remaining: 5.21ms
# 16:	learn: 0.0692898	total: 22ms	remaining: 3.88ms
# 17:	learn: 0.0689364	total: 23.3ms	remaining: 2.58ms
# 18:	learn: 0.0687353	total: 24.5ms	remaining: 1.29ms
# 19:	learn: 0.0683346	total: 25.8ms	remaining: 0us
# 0:	learn: 0.0774865	total: 1.36ms	remaining: 25.9ms
# 1:	learn: 0.0764600	total: 2.74ms	remaining: 24.7ms
# 2:	learn: 0.0755291	total: 4ms	remaining: 22.7ms
# 3:	learn: 0.0745964	total: 5.38ms	remaining: 21.5ms
# 4:	learn: 0.0738631	total: 6.67ms	remaining: 20ms
# 5:	learn: 0.0731261	total: 7.91ms	remaining: 18.5ms
# 6:	learn: 0.0729091	total: 9.08ms	remaining: 16.9ms
# 7:	learn: 0.0726243	total: 10.4ms	remaining: 15.6ms
# 8:	learn: 0.0720534	total: 11.7ms	remaining: 14.3ms
# 9:	learn: 0.0718260	total: 12.9ms	remaining: 12.9ms
# 10:	learn: 0.0711840	total: 14.3ms	remaining: 11.7ms
# 11:	learn: 0.0709639	total: 15.6ms	remaining: 10.4ms
# 12:	learn: 0.0703696	total: 16.9ms	remaining: 9.07ms
# 13:	learn: 0.0702345	total: 18.1ms	remaining: 7.74ms
# 14:	learn: 0.0697741	total: 19.3ms	remaining: 6.43ms
# 15:	learn: 0.0694588	total: 20.6ms	remaining: 5.14ms
# 16:	learn: 0.0692636	total: 21.8ms	remaining: 3.85ms
# 17:	learn: 0.0690021	total: 23ms	remaining: 2.56ms
# 18:	learn: 0.0688044	total: 24.2ms	remaining: 1.27ms
# 19:	learn: 0.0684118	total: 25.5ms	remaining: 0us

# %%
len(pred)
# Out:
# 57

# %%
MSEs
# Out:
# [0.0027901178015504063,
#  0.007748203445435707,
#  0.016327828018941417,
#  0.0034873183823911453,
#  0.010936553378969002,
#  0.008354254713591476,
#  0.0027199549789176892,
#  0.00813482030003643,
#  0.008716459084042654,
#  0.006715877662811192]

# %%
MSEs_arima
# Out:
# [0.0031755999502939562,
#  0.00850308499711265,
#  0.017468226112063646,
#  0.004007216020071928,
#  0.014576125932030837,
#  0.010183166919004288,
#  0.003205403006313849,
#  0.0139059697966677,
#  0.010453655320574852,
#  0.007425634066129838]

# %%
x = np.arange(len(MSEs))

width = 0.25  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(layout='constrained')

for attribute, measurement in [['Arima', MSEs_arima], ['Full', MSEs]]:
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    multiplier += 1
ax.legend(loc='upper left', ncols=2)
ax.set_xticks(x + width, combinations[:10])
ax.set_xlabel('[Strækning, Station]')
ax.set_ylabel('MSE')
ax.set_title('MSE per strækning per station')
ax.grid()

# %%
for strækning, station in combinations[:10]:
    y_test = data[(data['visualiseringskode'] == strækning) & (data['station'] == station)]['togpunktlighed'][initial_start:]
    plt.plot(y_test.index, y_test, color='red', label='Test Data')
    plt.plot(y_test.index, preds[(strækning,station)], color='green', marker='x',
                label='Predictions')
    plt.title(f'Strækning {strækning}, station {station}: Predictions & True Value')
    plt.xlabel('Dates')
    plt.ylabel('Togpunktlighed')
    plt.legend(loc='lower left')
    plt.show()

# %%
# Feature importance is numpy array
# Real for HPC
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pmdarima as pm
import xgboost as xgb
import ast
import catboost as cb

from matplotlib.ticker import MaxNLocator
from sklearn.ensemble import RandomForestRegressor
import warnings
warnings.filterwarnings('ignore')
from collections import defaultdict


# Import data
data = pd.read_csv("Data/Cleaned_data.csv")

#Unique combinations of strækning/station
combinations = data[['visualiseringskode', 'station']].drop_duplicates().values

# Retrieve best model parameters for ARIMA models for strækning/station
best_model_parameters = {}
model_params_sarima = pd.read_csv('Data/Best_model_parameters_SARIMA_strækning_station.csv')
list(model_params_sarima.items())
for i in range(model_params_sarima.shape[0]):
    tuple_result = ast.literal_eval(model_params_sarima['Key'][i])
    list_result = ast.literal_eval(model_params_sarima['Values'][i])
    best_model_parameters[tuple_result] = list_result

# Customized cross validation with rolling window and XGboost
def custom_cross_val_predict(estimator, y, X=None, cv=None, verbose=0, averaging="mean", return_raw_predictions=False, initial=2555):
    """Generate cross-validated estimates for each input data point
    
    Parameters
    ----------
    estimator : tuple
        A tuple containing two estimators. The first estimator should be the ARIMA model
        and the second one should be the Random Forest model.

    y : array-like or iterable, shape=(n_samples,)
        The time-series array.

    X : array-like, shape=[n_obs, n_vars], optional (default=None)
        An optional 2-d array of exogenous variables.

    cv : BaseTSCrossValidator or None, optional (default=None)
        An instance of cross-validation. If None, will use a RollingForecastCV.
        Note that for cross-validation predictions, the CV step cannot exceed
        the CV horizon, or there will be a gap between fold predictions.

    verbose : integer, optional
        The verbosity level.

    averaging : str or callable, one of ["median", "mean"] (default="mean")
        Unlike normal CV, time series CV might have different folds (windows)
        forecasting the same time step. After all forecast windows are made,
        we build a matrix of y x n_folds, populating each fold's forecasts like
        so::

            nan nan nan  # training samples
            nan nan nan
            nan nan nan
            nan nan nan
              1 nan nan  # test samples
              4   3 nan
              3 2.5 3.5
            nan   6   5
            nan nan   4

        We then average each time step's forecasts to end up with our final
        prediction results.

    return_raw_predictions : bool (default=False)
        If True, raw predictions are returned instead of averaged ones.
        This results in a y x h matrix. For example, if h=3, and step=1 then:

            nan nan nan # training samples
            nan nan nan
            nan nan nan
            nan nan nan
            1   4   2   # test samples
            2   5   7
            8   9   1
            nan nan nan
            nan nan nan

        First column contains all one-step-ahead-predictions, second column all
        two-step-ahead-predictions etc. Further metrics can then be calculated
        as desired.

    Returns
    -------
    predictions : array-like, shape=(n_samples,)
        The predicted values.

    """

    def indexable(*iterables):
        """Internal utility to handle input types"""
        results = []
        for iterable in iterables:
            if not hasattr(iterable, "__iter__"):
                raise ValueError("Input {!r} is not indexable".format(iterable))
            results.append(iterable)
        return results

    def check_cv(cv, initial = 2555):
        """Internal utility to check cv"""
        if cv is None:
            from pmdarima.model_selection import RollingForecastCV
            cv = RollingForecastCV(initial=initial, step=1, h=1)
        return cv

    def check_endog(y, copy=True, preserve_series=False):
        """Internal utility to check endogenous variable"""
        from pmdarima.utils import check_endog
        return check_endog(y, copy=copy, preserve_series=preserve_series)

    def _check_averaging(averaging):
        """Internal utility to check averaging"""
        if averaging == "mean":
            return np.nanmean
        elif averaging == "median":
            return np.nanmedian
        elif callable(averaging):
            return averaging
        else:
            raise ValueError("Unknown averaging method: {}".format(averaging))

    def _fit_and_predict(fold, estimator_tuple, y, X, train, test, verbose=1):
        """Internal utility to fit and predict"""
        arima_model = estimator_tuple
        # Fit ARIMA model
        arima_model.fit(y[train]) # X=X.iloc[train, :]
        # Predict with ARIMA model
        train_predictions = arima_model.predict_in_sample()
        arima_pred = arima_model.predict(n_periods=len(test))
        arima_pred_cap = np.array(max(min(1, arima_pred[0]), 0))
        # Calculate residuals for RF input
        arima_residuals_train = train_predictions - y[train]

        model = cb.CatBoostRegressor(objective = 'MAE', iterations=20, learning_rate=0.1, max_depth=5, verbose=0) 
        # Train the model
        #model = model.fit(D_train, steps, watchlist)
        model = model.fit(X.iloc[train,1:], arima_residuals_train)
        # Predict the labels of the test set
        #preds = model.predict(D_test)
        preds = model.predict(X.iloc[test,1:])
        # Overall prediction residuals = pred - true <=> true = pred - residuals
        overall_pred = np.array(max(min(1, arima_pred[0] - preds), 0)) # make sure it is in [0;1]

        return overall_pred, test, arima_pred_cap, model.feature_importances_ #arima_residuals_test

    y, X = indexable(y, X)
    y = check_endog(y, copy=False, preserve_series=True)
    cv = check_cv(cv, initial)
    avgfunc = _check_averaging(averaging)

    if cv.step > cv.horizon:
        raise ValueError("CV step cannot be > CV horizon, or there will be a gap in predictions between folds")

    prediction_blocks = [
        _fit_and_predict(fold,
                         estimator,
                         y,
                         X,
                         train=train,
                         test=test,
                         verbose=verbose,)  # TODO: fit params?
        for fold, (train, test) in enumerate(cv.split(y, X))]

    pred_matrix = np.ones((y.shape[0], len(prediction_blocks))) * np.nan
    arima_pred = []
    feature_importances = np.zeros((211,))
    for i, (pred_block, test_indices, arima_block, feature_importance) in enumerate(prediction_blocks):
        pred_matrix[test_indices, i] = pred_block
        arima_pred.append(arima_block)
        feature_importances += feature_importance


    if return_raw_predictions:
        predictions = np.ones((y.shape[0], cv.horizon)) * np.nan
        for pred_block, test_indices in prediction_blocks:
            predictions[test_indices[0]] = pred_block
        return predictions

    test_mask = ~(np.isnan(pred_matrix).all(axis=1))
    predictions = pred_matrix[test_mask]



    # Calculate CV score
    cv_scores = []
    cv_scores_arima = []
    for fold, (train, test) in enumerate(cv.split(y, X)):
        fold_predictions = pred_matrix[test, fold]
        fold_score = float(abs(y[test] - fold_predictions))
        fold_arima_score = float(abs(y[test] - arima_pred[fold]))
        cv_scores.append(fold_score)
        cv_scores_arima.append(fold_arima_score)

    # Compute overall CV score
    score = np.mean(cv_scores)
    arima_score = np.mean(cv_scores_arima)

    return avgfunc(predictions, axis=1), arima_pred, score,  arima_score, cv_scores, cv_scores_arima, feature_importances

# Get CV, errors and prediction for strækning/station
results_strækning_station = {}
combinations = data[['visualiseringskode', 'station']].drop_duplicates().values
MSEs = []
MSEs_arima = []
MSE_strækingstation = []
random_state = 42
preds = {}
cv_scores = {}
importance_features = np.zeros((211,))

for strækning, station in combinations[:2]:
    y = data[(data['visualiseringskode'] == strækning) & (data['station'] == station)]['togpunktlighed'].values
    X = data[(data['visualiseringskode'] == strækning) & (data['station'] == station)].iloc[:,1:]
    arima_model = pm.arima.ARIMA(order = best_model_parameters[strækning, station][0], seasonal_order=best_model_parameters[strækning, station][1])
    initial_start = y.shape[0] - 2
    pred_full, pred_arima, mse, mse_arima, cv_score, cv_score_arima, feature_importances = custom_cross_val_predict((arima_model), y, X, cv=None, verbose=1, averaging="mean", return_raw_predictions=False, initial=initial_start)
    # output = prediction per fold. 
    MSEs.append(mse)
    MSEs_arima.append(mse_arima)
    MSE_strækingstation.append(str((int(strækning), int(station))))
    preds[str((int(strækning), int(station))) + '_arima'] = pred_arima
    preds[str((int(strækning), int(station))) + '_full'] = pred_full
    cv_scores[str((int(strækning), int(station))) + '_arima'] = cv_score_arima
    cv_scores[str((int(strækning), int(station))) + '_full'] = cv_score
    importance_features += feature_importances

    # initial = 2457 - 100 fold, 10 combinations, n_estimators=100 -> 61 min

preds_dataframe = pd.DataFrame(preds)
cv_scores_dataframe = pd.DataFrame(cv_scores)
errors_dataframe = pd.DataFrame({'Strækning/station': MSE_strækingstation, 'Error_arima': MSEs_arima, 'Error_full': MSEs}) # Could easily be calculated from cv_scores?
importance_dataframe = pd.DataFrame(importance_features.reshape(1,-1), columns=list(data.columns[2:]))

preds_dataframe.to_csv('Results/SARIMA_Catboost_CV_preds.csv', index=False)
cv_scores_dataframe.to_csv('Results/SARIMA_Catboost_CV_scores.csv', index=False)
errors_dataframe.to_csv('Results/SARIMA_Catboost_CV_errors.csv', index = False)
importance_dataframe.to_csv('Results/SARIMA_Catboost_CV_importance.csv', index = False)
