# %%
import numpy as np 
import pandas as pd

# %%
errors = pd.read_csv('Data/SARIMA_strækning_errors.csv')

# %%
errors
# Out:
#      Unnamed: 0         0         1         2         3         4         5  \
# 0          2301 -0.197805  0.016392 -0.025102  0.016728 -0.062422 -0.017878
# 1          2302 -0.092113  0.011807 -0.126524  0.034860  0.194835  0.070984
# 2          2303 -0.341119  0.008505 -0.163943 -0.051324  0.030721 -0.085852
# 3          2304 -0.248299  0.006126  0.218602 -0.021768  0.189334 -0.009597
# 4          2305 -0.223887  0.004413  0.072216 -0.034615 -0.154668 -0.051750
# ..          ...       ...       ...       ...       ...       ...       ...
# 251        2552  0.043983  0.034395  0.032550 -0.005284 -0.063034  0.064063
# 252        2553 -0.079015 -0.107346 -0.094282 -0.084781 -0.039527 -0.091363
# 253        2554  0.002797 -0.029458 -0.049996  0.026655 -0.085142 -0.051140
# 254        2555 -0.022122  0.056046 -0.028525 -0.065061 -0.045515 -0.063527
# 255        2556 -0.039649 -0.081561 -0.029350  0.001184 -0.140055 -0.009631
#
# ...
